# %% [markdown]
# # Subset of NL Stock Market represented by companies that are part of the AEX Index
# [The AEX index](https://en.wikipedia.org/wiki/AEX_index#cite_note-12) is a free float market capitalization-weighted index composed of 30 large capitalization Dutch companies that trade on Euronext Amsterdam. It makes up approximately 75% of Dutch listed stock market. Before 22<sup>nd</sup> September 2025, the index had 25 consituent components and was capitalization-weighted. Even though it still is captalization-weighted, as of 22<sup>nd</sup> September the share of individual companies is capped to 15% in case one exceeds this threshold. So far only ASML Holding's 33% share in the cumulative capitalization of AEX companies is subject to this rule. In this notebook I ignore it and present data on a pure capitalization-weighted basis. If you want to use the 15% capitalization capping rule, please uncomment cell 5 in this notebook.
#
# In this notebook I look at:
# * the market capitalization of listed domestic companies that are part of the Stoxx Europe 600 Banks index
# * the total annual and daily value of stocks traded that belong to the index
# * the annual and daily turover rations of stocks traded that belong to the index
# * the forward annual dividend yield of banks that are part of the index
# * the forward price to earnings ratio of banks that are part of the index
# * the P/B and ROEs of banks that are part of the index and their cost of equity
#
# I created my own module called `stock_market.metrics` (which is part of this repository) where I calculate capitalization, turnover, forward dividend yields and volatility of an arbitrary stock market with the help of the [yfinance](https://pypi.org/project/yfinance/) module. I use it to provide metrics on companies that are part of the AEX Index.

# %%
# Uncomment if running in Google Colaboratory, otherwise the import of the curves module in the cell below will fail
# !git clone -l -s https://github.com/ilchen/EU_Economic_Data_Analysis.git cloned-repo
# %cd cloned-repo

# Install the latest version of pandas-datareader and yfinance
# !pip install pandas-datareader -U
# !pip install yfinance -U
# !pip install eurostat -U

# %%
import pandas as pd
from pandas.tseries.offsets import YearBegin
import numpy as np
import scipy
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yfin
import eurostat

from datetime import date

from stock_market import metrics, currency_converters, CapChangePlotter

# %%
# Human readable column names for DataFrames
MKT_CAP_AEX = 'Market capitalization of AEX companies'
MKT_CAP_TOP10_AEX = 'Top-10 AEX companies by market capitalization and their share in the total market cap of AEX companies'
MKT_CAP_AEX_TO_GDP = MKT_CAP_AEX + ' (% of GDP)'
TRAD_VOL = 'Stocks traded, total value'
TRAD_VOL_AEX_GRAPH_TITLE = 'AEX ' + TRAD_VOL + ' (annualized)'
TRAD_VOL_AEX_GRAPH_TITLE_DAILY = 'AEX ' + TRAD_VOL + ' (average daily)'
TUROVER_RATIO_AEX = 'Turnover ratio of AEX companies shares (%)'
TUROVER_RATIO_AEX_GRAPH_TITLE = 'Stocks traded, Annual ' + TUROVER_RATIO_AEX
TUROVER_RATIO_AEX_DAILY_GRAPH_TITLE = 'Stocks traded, Daily ' + TUROVER_RATIO_AEX
EXCESS_RETURN_AEX = 'Excess Annual Return of AEX over 1-year Riskless rate'
VOLATILITY_AEX = 'Volatility of AEX'
EXCESS_RETURN_AEX = 'Excess Annual Return of AEX over 1-year Riskless rate'
SHARPE_RATIO_AEX = 'Sharpe Ratio of AEX (with volatility over {:d} years)'

# Y axis labels for graphs
LEFT_Y_AXIS_LABEL = 'Billions of Euros'
RIGHT_Y_AXIS_LABEL = '% of NL GDP'

TTM_SUFFIX = ' (ttm)'
MRQ_SUFFIX = ' (mrq)'

# %%
import logging
logging.getLogger("yfinance").setLevel(logging.CRITICAL)

start = date(2021, 1, 1)
aex_components = metrics.NLStockMarketMetrics.get_aex_historical_components(start)
aex_hist_shares_outs = metrics.NLStockMarketMetrics.get_aex_historical_shares_outstanding()
aex_metrics = metrics.NLStockMarketMetrics(aex_components, start=start, hist_shares_outs=aex_hist_shares_outs)
# Out:
# [*********************100%***********************]  36 of 36 completed
# Correcting the number of shares outstanding for EXO.AS from 328677120 to 202231958
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Uncomment the cell below if you want to apply AEX new capitalization capping rules.

# %%
# # Uncomment if you want to apply the 15% capitalization capping rules
# threshold = .15
# for index, row in aex_metrics.capitalization.loc['2025-09-22':].iterrows():
#     tot_cap = row.iloc[0]
#     to_cap = row.iloc[2:][row.iloc[2:]/tot_cap > threshold]
#     for idx, value in to_cap.items():
#         new_cap = tot_cap * threshold
#         aex_metrics.capitalization.loc[index, idx] = new_cap
#         aex_metrics.capitalization.loc[index, aex_metrics.CAPITALIZATION] -= value - new_cap

# %%
# A look-up map from ticker symbols to displayable names
names = aex_metrics.tickers_to_display_names(aex_metrics.get_current_components())
ticker_to_name = dict(zip(aex_metrics.get_current_components(), names))

# %%
# Convert into billions of Euros
aex_capitalization = aex_metrics.get_capitalization(frequency='ME', method='last') / 1e9
aex_annual_trading_value = aex_metrics.get_annual_trading_value(frequency='ME') / 1e9
aex_daily_trading_value = aex_metrics.get_daily_trading_value(frequency='ME') / 1e9

aex_daily_turnover = aex_metrics.get_daily_turnover(frequency='ME')
aex_annual_turnover = aex_metrics.get_annual_turnover(frequency='ME')

aex_volatility = aex_metrics.get_annual_volatility(frequency='ME')

# %%
# Querying for seasonally adjusted nominal NL GDP data
gdp = eurostat.get_data_df('namq_10_gdp', filter_pars={
    'startPeriod': (start-YearBegin(1)).date(), 'unit': 'CP_MEUR', 's_adj': 'SCA', 'na_item': 'B1GQ', 'geo': 'NL'}).iloc[:, 4:]
gdp = gdp.set_index(gdp.columns[0]).T
gdp = gdp.set_axis(pd.DatetimeIndex(gdp.index, 'QS'))

# Eurostat publishes quarterly GDP data at quarterly volumes. To calculate the annual rate of GDP growth
# I either sum up the non-seasonally adjusted GDP over the last 4 quarters or multiply a seasonally-adjusted one by 4.
#gdp = gdp.rolling(4).sum().dropna().loc[:, 'NL']
gdp = gdp.loc[:, 'NL'] * 4
gdp.rename('NL GDP', inplace=True)

# Upsampling to monthly frequencies to match the frequency of AEX metrics and converting to billions of Euros
gdp = gdp.resample('ME').ffill()  / 1e3 

missing_months = aex_capitalization.index.difference(gdp.index)
gdp = pd.concat([gdp, pd.Series(np.nan, index=missing_months)]).sort_index().ffill()

# %%
stock_mkt_aex = pd.concat([aex_capitalization, aex_capitalization / gdp, aex_annual_trading_value, aex_daily_turnover], axis=1, sort=False)
stock_mkt_aex.columns = [MKT_CAP_AEX, MKT_CAP_AEX_TO_GDP, TRAD_VOL, TUROVER_RATIO_AEX]
stock_mkt_aex.dropna(inplace=True)

# %% [markdown]
# In the below table **_Stocks traded, total value_** represents a cumulative annual amount of all transactions in shares of companies in the AEX. **_Turnover ratio of AEX components_** represents the percentage of shares outstanding that are traded per day.

# %%
pd.options.display.float_format = (lambda x: '{:.2%}'.format(x) if x < 5 else '€{:,.2f}bn'.format(x))
pd.options.display.max_rows = 40
stock_mkt_aex
# Out:
#             Market capitalization of AEX companies  \
# Date
# 2021-01-31                               €949.76bn
# 2021-02-28                             €1,042.31bn
# 2021-03-31                             €1,035.92bn
# 2021-04-30                             €1,043.58bn
# 2021-05-31                             €1,048.13bn
# ...                                            ...
# 2026-02-28                             €1,494.95bn
# 2026-03-31                             €1,392.89bn
# 2026-04-30                             €1,447.48bn
# 2026-05-31                             €1,507.52bn
# 2026-06-30                             €1,576.88bn
#
#             Market capitalization of AEX companies (% of GDP)  \
# Date
# 2021-01-31                                            112.43%
# 2021-02-28                                            123.38%
# 2021-03-31                                            122.63%
# 2021-04-30                                            117.59%
# ...

# %% [markdown]
# ## Market capitalization of companies in the AEX index

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax2 = ax.twinx()
ax.bar(x=range(len(stock_mkt_aex)), height=stock_mkt_aex.iloc[:,0], color='#1f77b4',
       width=0.5, label=MKT_CAP_AEX)
ax2.plot(range(len(stock_mkt_aex)), stock_mkt_aex.iloc[:,1], color='k', marker='o',
         label=MKT_CAP_AEX_TO_GDP, linestyle='--', linewidth=2)
ax.legend(loc='upper left')
ax2.legend(loc='upper right')
ax.title.set_text(MKT_CAP_AEX)
ax.grid(True)
ax2.grid(False)
ax.margins(x=0)
ax.set_xticks(range(len(stock_mkt_aex)), stock_mkt_aex.index)
ax.set_xticklabels(stock_mkt_aex.index.strftime('%Y-%m'), rotation=45)
#ax.set_yticks(np.arange(0, 51000, 5000))
ax.set_ylabel(LEFT_Y_AXIS_LABEL)
ax.yaxis.set_major_formatter('{x:,.0f}')
ax2.set_ylabel(RIGHT_Y_AXIS_LABEL)
ax2.yaxis.set_major_formatter(mtick.PercentFormatter(1, decimals=0))

# %% [markdown]
# ### Top-10 companies by their capitalization and their share in the total capitalization of AEX companies

# %%
top10_today = aex_metrics.get_top_n_capitalization_companies_for_day(
    10, merge_additional_share_classes=True)
top10_last_month = aex_metrics.get_top_n_capitalization_companies_for_month(
    10, aex_metrics.data.index[-1] - pd.DateOffset(months=+1), method='last')
top10_year_ago = aex_metrics.get_top_n_capitalization_companies_for_month(
    10, aex_metrics.data.index[-1] - pd.DateOffset(months=+12), method='last')

# Calculate metrics for the previous 4 years
num_years = 4
years = list(range(aex_metrics.data.index[-1].year-num_years, aex_metrics.data.index[-1].year))
top10_last_n_years = [aex_metrics.get_top_n_capitalization_companies_for_year(10, date(year, 1, 1), method='last') for year in years]

# %%
# Convert into Billions of Euros
top10 = list(map(lambda df: df.Capitalization, top10_last_n_years))
top10.append(top10_today.Capitalization)
top10 = pd.concat(top10, axis=1) / 1e9
columns = [aex_metrics.CAPITALIZATION + f' YE {year}' for year in years]
columns.append(' now')
top10.columns = columns

top10_pct = list(map(lambda df: df.iloc[:,1], top10_last_n_years))
top10_pct.append(top10_today.iloc[:,1])
top10_pct = pd.concat(top10_pct, axis=1)

# %%
ax = top10.T.plot.bar(figsize=(20,10), title=MKT_CAP_TOP10_AEX, edgecolor='white',
                      stacked=True, rot=0, ylabel=LEFT_Y_AXIS_LABEL)
ax.yaxis.set_major_formatter('{x:,.0f}')
ax.get_legend().remove()
for c in ax.containers:
    labels = [c.get_label() + f': {a:,.0f}bn, {top10_pct.loc[c.get_label()].iloc[i]:.2%}'
              if a else '' for i, a in enumerate(c.datavalues)]
    ax.bar_label(c, labels=labels, label_type="center", color='white', fontsize=9)
ax.grid(axis='y', linestyle='--', alpha=0.7)

# %% [markdown]
# ### Capitalization: Last Business Day vs. End of Previous Month or End of Previous Year
# Please adjust the comment in the below cell to determine if you'll be comparing the current capitalization to that of the previous month end or that of the prevopus year end.

# %%
top10_now = pd.concat([top10_last_month.Capitalization, top10_today.Capitalization], axis=1) / 1e9
top10_now.columns = [aex_metrics.CAPITALIZATION + sfx for sfx in [' last month', ' now']]
top10_today_pct = pd.concat([top10_last_month.iloc[:,1], top10_today.iloc[:,1]], axis=1)

# Uncomment if you want to compare with the capitalization at the end of the prevous year
top10_now = pd.concat([top10_last_n_years[-1].Capitalization, top10_today.Capitalization], axis=1) / 1e9
next_bd = aex_metrics.data.index[-1] + pd.offsets.BDay(1)
ye = pd.offsets.YearEnd().rollforward(aex_metrics.data.index[-1])
top10_now.columns = [aex_metrics.CAPITALIZATION + sfx for sfx in [f' YE {aex_metrics.data.index[-1].year-1}',
                                                                   ' now' if next_bd < ye else f'YE {aex_metrics.data.index[-1].year}']]
top10_today_pct = pd.concat([top10_last_n_years[-1].iloc[:,1], top10_today.iloc[:,1]], axis=1)

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ax = top10_now.T.plot.bar(ax=ax, stacked=True, rot=0, edgecolor='white', linewidth=0.8, width=0.8, fontsize=9)
ax.set_title(MKT_CAP_TOP10_AEX, fontsize=10)
ax.set_ylabel(LEFT_Y_AXIS_LABEL, fontsize=10)
ax.yaxis.set_major_formatter('{x:,.0f}')
ax.get_legend().remove()

# Clean labels
for c in ax.containers:
    labels = [f"{ticker_to_name.get(c.get_label(), c.get_label())}: {a:,.0f}bn ({top10_today_pct.loc[c.get_label()].iloc[i]:.1%})" if a else '' 
              for i, a in enumerate(c.datavalues)]
    ax.bar_label(c, labels=labels, label_type="center", fontsize=9, color='white', fontweight='bold')

ax.grid(axis='y', linestyle='--', alpha=0.7)

# %%
cur_month = aex_metrics.data.index[-1].month
# In billions of EUR
cap_now = aex_metrics.capitalization.iloc[-1,0] / 1e9
cap_end_last_year = stock_mkt_aex.iloc[-cur_month-1, 0]
print(f'The capitalization of AEX on {aex_metrics.capitalization.index[-1]:%Y-%m-%d} is €{cap_now:.2f}bn')
print(f'It is {cap_now / gdp.iloc[-1]:.2%} of NL GDP')

print(f'It changed by €{(cap_now - cap_end_last_year):+.2f}bn ({cap_now / cap_end_last_year - 1:+.2%}) '
      f'compared with {stock_mkt_aex.index[-cur_month-1]:%Y-%m-%d}')
print(f'And its share of GDP changed by {stock_mkt_aex.iloc[-1,1]-stock_mkt_aex.iloc[-cur_month-1,1]:+.2%} '
      f'compared with {stock_mkt_aex.index[-cur_month-1]:%Y-%m-%d}')
# Out:
# The capitalization of AEX on 2026-06-26 is €1576.88bn
# It is 130.56% of NL GDP
# It changed by €+226.91bn (+16.81%) compared with 2025-12-31
# And its share of GDP changed by +17.98% compared with 2025-12-31

# %% [markdown]
# ### Capitalization: Last Business Day vs. End of Same Month Last Year
# You can adjust this section to also present a difference in the capitalization between two arbitrary years in the past. Please uncomment the relevant lines in cell 21.

# %%
top10_now = pd.concat([top10_year_ago.Capitalization, top10_today.Capitalization], axis=1) / 1e9
top10_now.columns = [aex_metrics.CAPITALIZATION + sfx for sfx in [' year ago', ' now']]
top10_today_pct = pd.concat([top10_year_ago.iloc[:,1], top10_today.iloc[:,1]], axis=1)

# Uncomment if you want to compare the capitalization between different years in the past
# years_ago = [-2, -1]
# top10_now = pd.concat([top10_last_n_years[years_ago[0]].Capitalization, top10_last_n_years[years_ago[1]].Capitalization], axis=1) / 1e9
# top10_now.columns = [aex_metrics.CAPITALIZATION + sfx for sfx in
#                      [f' YE {aex_metrics.data.index[-1].year + years_ago[0]}', f' YE {aex_metrics.data.index[-1].year + years_ago[1]}']]
# top10_today_pct = pd.concat([top10_last_n_years[years_ago[0]].iloc[:,1], top10_last_n_years[years_ago[1]].iloc[:,1]], axis=1)

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ax = top10_now.T.plot.bar(ax=ax, stacked=True, rot=0, edgecolor='white', linewidth=0.8, width=0.8, fontsize=9)
ax.set_title(MKT_CAP_TOP10_AEX, fontsize=10)
ax.set_ylabel(LEFT_Y_AXIS_LABEL, fontsize=10)
ax.yaxis.set_major_formatter('{x:,.0f}')
ax.get_legend().remove()

# Clean labels
for c in ax.containers:
    labels = [f"{ticker_to_name.get(c.get_label(), c.get_label())}: {a:,.0f}bn ({top10_today_pct.loc[c.get_label()].iloc[i]:.1%})" if a else '' 
              for i, a in enumerate(c.datavalues)]
    ax.bar_label(c, labels=labels, label_type="center", fontsize=9, color='white', fontweight='bold')

ax.grid(axis='y', linestyle='--', alpha=0.7)

# %%
print('The capitalization of Top-10 changed by '
      f'{(top10_now.iloc[:, 1].sum()-top10_now.iloc[:, 0].sum())/top10_now.iloc[:, 0].sum():+.2%} from a year ago')
# Out:
# The capitalization of Top-10 changed by +28.68% from a year ago

# %%
print(f'The capitalization of AEX companies on {aex_metrics.capitalization.index[-1]:%Y-%m-%d} is '
      f'€{aex_metrics.capitalization.iloc[-1,0]/1e9:.2f}bn')
# Out:
# The capitalization of AEX companies on 2026-06-26 is €1576.88bn

# %%
cap_year_ago = aex_capitalization.iloc[-13]
pct_change_over_year_all = (aex_metrics.capitalization.iloc[-1,0]/1e9 - cap_year_ago) / cap_year_ago
print(f'It changed by {pct_change_over_year_all:+.2%} from {aex_capitalization.index[-13]:%Y-%m-%d}')
print(f'The capitalization of AEX companies on {aex_capitalization.index[-13]:%Y-%m-%d} was €{cap_year_ago:.2f}bn')

ye_prev_year = aex_metrics.capitalization.index[-1]-pd.offsets.YearEnd(1)
ye_two_years_ago = aex_metrics.capitalization.index[-1]-pd.offsets.YearEnd(2)

print(f'\nThe capitalization of AEX companies on YE {ye_prev_year:%Y-%m-%d} was '
      f'€{aex_capitalization.loc[ye_prev_year]:.2f}bn')
pct_change_over_year_ago = aex_capitalization.loc[ye_prev_year] / aex_capitalization.loc[ye_two_years_ago] - 1

print(f'It changed by {pct_change_over_year_ago:+.2%} over {aex_metrics.data.index[-1].year-1}')
print(f'The capitalization of AEX companies on YE {ye_two_years_ago:%Y-%m-%d} was '
      f'€{aex_capitalization.loc[ye_two_years_ago]:.2f}bn')
# Out:
# It changed by +27.43% from 2025-06-30
# The capitalization of AEX companies on 2025-06-30 was €1237.42bn
#
# The capitalization of AEX companies on YE 2025-12-31 was €1349.98bn
# It changed by +10.73% over 2025
# The capitalization of AEX companies on YE 2024-12-31 was €1219.13bn

# %% [markdown]
# ## The AEX's top-7 and their capitilization changes
# Let's have a look at the AEX's top-7 companies by capitalization and how it has been changing over the past few years

# %%
top7 = top10_now.iloc[:,1].sort_values(ascending=False).iloc[:7].index.to_list()

# %%
magn_seven = aex_metrics.get_capitalization_for_companies(top7, 'B')
magn_seven_cum_cap = magn_seven.iloc[:,1:].sum(axis=1)
print(f'The top Seven constituent companies in AEX make up '
      f'{magn_seven_cum_cap.iloc[-1]/magn_seven.iloc[-1,0]:.2%} of the index')
print(f'With a cumulative capitalization of €{magn_seven_cum_cap.iloc[-1]/1e12:.3f}trn')
# Out:
# The top Seven constituent companies in AEX make up 73.70% of the index
# With a cumulative capitalization of €1.162trn

# %% [markdown]
# ### Capitalization development of the top seven stocks since 2021

# %%
magn_seven_weekly = magn_seven.iloc[:,1:].resample('W').mean() / 1e9
magn_seven_weekly = magn_seven_weekly.loc[:, magn_seven_weekly.iloc[-1].sort_values(ascending=False).index]
ax = magn_seven_weekly.plot.area(figsize=(20,10), grid=True, title="AEX top seven's Capitalization",
                                 xticks=magn_seven_weekly.index[::6], xlabel='', rot=45,
                                 ylabel=LEFT_Y_AXIS_LABEL)
ax.legend(ax.collections, magn_seven_weekly.columns.map(lambda ticker: ticker_to_name[ticker] + f' ({ticker})'))
ax.yaxis.set_major_formatter('{x:,.0f}')
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, magn_seven_weekly.index[::6])))

# %% [markdown]
# ## Total annual and daily value of AEX companies' stocks traded
# For AEX companies I depict average daily trading values over each month. In the first graph I show average daily volumes per month, in the second I show average daily volues per month scaled to annual ammounts.

# %%
ax = aex_daily_trading_value.plot.bar(figsize=(20,10), grid=True, ylabel=LEFT_Y_AXIS_LABEL,
                                      title=TRAD_VOL_AEX_GRAPH_TITLE_DAILY, color='#1f77b4',
                                      xlabel='', rot=45)
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, aex_daily_trading_value.index)))

# %%
ax = aex_annual_trading_value.plot.bar(figsize=(20,10), grid=True, ylabel=LEFT_Y_AXIS_LABEL,
                                         title=TRAD_VOL_AEX_GRAPH_TITLE, color='#1f77b4',
                                         xlabel='', rot=45)
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, aex_annual_trading_value.index)))

# %% [markdown]
# ## Stocks traded, annual and daily turnover ratios of AEX companies' shares to their capitalization
# In this section of the notebook I look at the turnover ratio of AEX companies' shares traded divided by their market capitalization. The value is annualized by multiplying the monthly average by 12.
#
# If you divide the number for a given year by 252 (the approximate number of trading days), you obtain the percentage of shares that are traded in one day. This ranges between 0.2% and 1%. And such a small fraction of traded shares determine the capitalization of the whole firm.

# %%
ax = aex_annual_turnover.dropna().plot(figsize=(20,10), grid=True, title=TUROVER_RATIO_AEX_GRAPH_TITLE,
                                       color='k', marker='o', linestyle='--', linewidth=2,
                                       xticks=aex_annual_turnover.index, xlabel='', rot=45)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, aex_annual_turnover.index)))

# %%
ax = aex_daily_turnover.plot(figsize=(20,10), grid=True,
                             title=TUROVER_RATIO_AEX_DAILY_GRAPH_TITLE, color='k', marker='o', linestyle='--',
                             linewidth=2, xticks=aex_daily_turnover.index, xlabel='', rot=45)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, aex_daily_turnover.index)))

# %% [markdown]
# ## Volatility of a subset of NL Stock Market represented by AEX companies
# In this section of the notebook I look at the annual volatility of the subset of the NL Stock Market represented by companies that are part of the AEX index. I use an exponentially weighted moving average approach to calculate historical volatility with a λ = 0.94453.

# %%
ax = aex_volatility.plot.bar(figsize=(20,10), grid=True, title=VOLATILITY_AEX, xlabel='', rot=45)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, aex_volatility.index)))

# %% [markdown]
# ## Excess return of a subset of the NL Stock Market represented by AEX companies over riskless rate
# In this section of the notebook I look at the excess annual return of AEX over 1-year riskless annual rate implied by yields on Eurozone AAA-rated Euro Area government bonds at 1-Year constant maturity converted into a zero-rate with annual compounding.
#
# $${Excess Return}_{AEX} = {R_{AEX} - R_{riskless}}$$
# where:
# * $R_{AEX}$ &mdash; annual return on AEX
# * $R_{riskless}$ &mdash; riskless annual return (e.g. as given by AAA-rated government bonds at 1-Year maturity)

# %%
aex_excess_return = aex_metrics.get_excess_return(years=2, frequency='MS')

# %%
ax = aex_excess_return.plot.bar(figsize=(20,10), grid=True, title=EXCESS_RETURN_AEX, xlabel='', rot=45, x_compat=True)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, aex_excess_return.index)))

# %% [markdown]
# ## The Sharpe ratio of a subset of the NL Stock Market represented by AEX companies
# In this section of the notebook I look at the ex-post Sharpe ratio of AEX. It is a measure of the performance of an investment in AEX compared to a risk-free asset, after adjusting for its risk.
#
# $$S_{AEX} = \frac{R_{AEX} - R_{riskless}}{\sigma_{AEX}}$$
# where:
# * $R_{AEX}$ &mdash; annual return on AEX
# * $R_{riskless}$ &mdash; riskless annual return (e.g. as implied by AAA-rated Euro Area government bonds at 1-Year maturity)
# * $\sigma_{AEX}$ &mdash; volatility of AEX

# %%
aex_sharpe_ratio = aex_metrics.get_sharpe_ratio(years=2, frequency='MS')

# %%
ax = aex_sharpe_ratio.plot.bar(figsize=(20,10), grid=True,
                               title=SHARPE_RATIO_AEX.format(2), xlabel='', rot=45, x_compat=True)
ax.yaxis.set_major_formatter('{x:.2f}')
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, aex_sharpe_ratio.index)))

# %% [markdown]
# ## Forward annual dividend yield of AEX companies

# %%
print(f'AEX companies forward dividend yield on {aex_metrics.data.index[-1]:%Y-%m-%d} is '
      f'{aex_metrics.forward_dividend_yield:.5}%')
# Out:
# AEX companies forward dividend yield on 2026-06-26 is 2.184%

# %% [markdown]
# ## Forward Price to Earnings ratio of AEX companies

# %%
print(f'AEX companies forward P/E on {aex_metrics.data.index[-1]:%Y-%m-%d} is '
      f'{aex_metrics.forward_PE:.2f}')
# Out:
# AEX companies forward P/E on 2026-06-26 is 15.22

# %% [markdown]
# ## A sector breakdown for the AEX
# Understanding the sector breakdown of the AEX is key for investors, as it sheds light on the market’s exposure to different industries. Let’s examine the the current sector breakdown, based on the relative market capitalization of companies within each sector. Notably, the technology sector dominates with 28.68% of the total capitalization, as shown in the below chart.

# %%
sector_bd = aex_metrics.get_sector_breakdown_for_day().sort_values()
sector_bd = sector_bd.set_axis(sector_bd.index.map(lambda key: yfin.Sector(key).name))
ax = sector_bd.plot.pie(
    figsize=(20,10), grid=True, ylabel='',
    autopct=lambda pct: f'{pct:.2f}%', pctdistance=0.85,
    wedgeprops={'edgecolor': 'black', 'linewidth': 1},
    title=f'AEX sector breakdown on {aex_metrics.data.index[-1]:%Y-%m-%d}')

# %% [markdown]
# ## Year to Date (YTD) changes in capitalization for companies in the AEX index
# You can also visualize capitalization changes over the whole of previous year by uncommenting a few lines in the cell below.

# %%
cur_month = aex_metrics.data.index[-1].month
offset = offset2 = 0

# Uncomment if you want to compare capitalization changes over the previous year
# offset = 0 if cur_month == 12 else cur_month
# offset2 = 0 if cur_month == 12 else 12
    
cap = aex_metrics.get_capitalization_for_companies(aex_metrics.get_current_components(), method='last')
cap_now = cap.iloc[-1 - offset]
cap_end_last_year = cap.iloc[-cur_month - 1 - offset2]
cap_df = (pd.concat([cap_end_last_year, cap_now], axis=1) / 1e9).dropna()

next_bd = aex_metrics.data.index[-1] + pd.offsets.BDay(1)
ye = pd.offsets.YearEnd().rollforward(aex_metrics.data.index[-1])
cap_df.columns = [aex_metrics.CAPITALIZATION + sfx for sfx in [f' YE {cap.index[-cur_month - 1 - offset2].year}',
                                                                 f' YE {cap.index[-1 - offset].year}' if ye < next_bd else ' now']]
TITLE_PFX = f' YE {cap.index[-cur_month - 1 - offset2].year} to ' + (f'YE {cap.index[-1 - offset].year}' if ye < next_bd  or offset else 'now')

# %%
cap_chg = cap_df.iloc[1:].pct_change(axis=1, fill_method=None).iloc[:, 1].sort_values()
cap_chg
# Out:
# ADYEN.AS   -39.98%
# WKL.AS     -36.44%
# PRX.AS     -30.95%
# REN.AS     -23.72%
# UMG.AS     -17.43%
# CVC.AS     -13.38%
# EXO.AS      -7.39%
# UNA.AS      -5.40%
# AD.AS        0.40%
# AKZA.AS      2.07%
# IMCD.AS      3.61%
# WDP.BR       4.15%
# SHELL.AS     4.28%
# PHIA.AS      5.07%
# HEIA.AS      6.11%
# ASRNL.AS     7.95%
# KPN.AS       9.06%
# INGA.AS     11.85%
# AGN.AS      12.11%
# MICC.AS     12.56%
# DSFIR.AS    13.88%
# NN.AS       15.27%
# ABN.AS      20.66%
# MT.AS       33.64%
# INPST.AS    47.32%
# ASML.AS     70.08%
# ASM.AS      83.09%
# BESI.AS    112.32%
# Name: Capitalization now, dtype: float64

# %%
plotter = CapChangePlotter(cap.index[-cur_month - 1 - offset2], name_expander=ticker_to_name.get)
_ = plotter.plot_cap_change_bars(changes=cap_chg, mode="mixed", cut_off=30)

# %% [markdown]
# ### Revenue, Income, CAPEX, Acquisitions, and Dividends Growth of all AEX Companies

# %%
cur_conv_df = currency_converters.EuroCurrencyConverter(['USD', 'GBp'], start).get_currency_conversion_df()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
istmt, sector_istmt = aex_metrics.get_annual_stmt_data(3, cur_conv_df)

# %%
# Querying for GDP deflator
gdp_dfl = eurostat.get_data_df('nama_10_gdp', filter_pars={
    'startPeriod': (start-YearBegin(4)).date(), 'unit': 'PD20_EUR', 'na_item': 'B1GQ', 'geo': 'NL'}).iloc[:, 4:].T
gdp_dfl = gdp_dfl.set_axis(pd.DatetimeIndex(gdp_dfl.index, 'YS')).resample('YE').last().iloc[:,0]
gdp_dfl_coef = (gdp_dfl / gdp_dfl.shift(1)).dropna()

# %%
yoy_growth = istmt.iloc[:,::-1].pct_change(axis=1, fill_method=None).dropna(axis=1)
yoy_growth_real = (yoy_growth + 1.).divide(gdp_dfl_coef, axis=1) - 1.
yoy_growth_ly = pd.concat([yoy_growth.iloc[:,-1], yoy_growth_real.iloc[:,-1]],
                          axis=1, keys=['Nominal', 'Real'])
yoy_growth_ly = yoy_growth_ly.reindex(yoy_growth.index[[0,1,3,2,4,5,6]])

# %%
ax = yoy_growth_ly.plot.bar(figsize=(20,10), grid=True, rot=45, width=0.2,
                            title=f'AEX Companies Financials: YoY Change in {istmt.columns[0].year}, %')
ax.yaxis.set_major_formatter('{x:,.0%}')
for container in ax.containers:
    ax.bar_label(container, fmt='{:.1%}', label_type='edge', fontsize=10, padding=3,
                 bbox=dict(facecolor='white', edgecolor='none', alpha=0.85, boxstyle='round,pad=0.2'))

# %%
istmt_tech = sector_istmt['technology']
yoy_growth_tech = istmt_tech.iloc[:,::-1].pct_change(axis=1, fill_method=None).dropna(axis=1)
yoy_growth_real_tech = (yoy_growth_tech + 1.).divide(gdp_dfl_coef, axis=1) - 1.
yoy_growth_tech_ly = pd.concat([yoy_growth_tech.iloc[:,-1], yoy_growth_real_tech.iloc[:,-1]],
                          axis=1, keys=['Nominal', 'Real'])
yoy_growth_tech_ly = yoy_growth_tech_ly.reindex(yoy_growth_tech.index[[0,1,3,2,4,5,6]])
yoy_growth_tech_ly = yoy_growth_tech_ly[~np.isinf(yoy_growth_tech_ly)].dropna()

# %%
ax = yoy_growth_tech_ly.plot.bar(figsize=(20,10), grid=True, rot=45, width=0.2,
                                 title=f'AEX Technology Sector Financials: YoY Change in {istmt.columns[0].year}, %')
ax.yaxis.set_major_formatter('{x:,.0%}')
for container in ax.containers:
    ax.bar_label(container, fmt='{:.1%}', label_type='edge', fontsize=10, padding=3,
                 bbox=dict(facecolor='white', edgecolor='none', alpha=0.85, boxstyle='round,pad=0.2'))

# %%
for ticker in aex_metrics.get_current_components():
    print(ticker + ': ' + aex_metrics.tickers.tickers[ticker].info['sectorKey'])
# Out:
# AKZA.AS: basic-materials
# CVC.AS: financial-services
# SBMO.AS: energy
# ASML.AS: technology
# KPN.AS: communication-services
# REN.AS: industrials
# IMCD.AS: basic-materials
# UNA.AS: consumer-defensive
# ABN.AS: financial-services
# INGA.AS: financial-services
# AGN.AS: financial-services
# EXO.AS: industrials
# DSFIR.AS: basic-materials
# MICC.AS: consumer-defensive
# BESI.AS: technology
# WKL.AS: industrials
# NN.AS: financial-services
# HEIA.AS: consumer-defensive
# AALB.AS: industrials
# PRX.AS: consumer-cyclical
# PHIA.AS: healthcare
# UMG.AS: communication-services
# MT.AS: basic-materials
# AD.AS: consumer-defensive
# ADYEN.AS: technology
# ASRNL.AS: financial-services
# WDP.BR: real-estate
# SHELL.AS: energy
# INPST.AS: industrials
# ASM.AS: technology

# %%
istmt_energy = sector_istmt['energy']
yoy_growth_energy = istmt_energy.iloc[:,::-1].pct_change(axis=1, fill_method=None).dropna(axis=1)
yoy_growth_real_energy = (yoy_growth_energy + 1.).divide(gdp_dfl_coef, axis=1) - 1.
yoy_growth_energy_ly = pd.concat([yoy_growth_energy.iloc[:,-1], yoy_growth_real_energy.iloc[:,-1]],
                                 axis=1, keys=['Nominal', 'Real'])
yoy_growth_energy_ly.reindex(yoy_growth_energy.index[[0,1,3,2,4,5,6]])
yoy_growth_energy_ly = yoy_growth_energy_ly[~np.isinf(yoy_growth_energy_ly)].dropna()

# %%
print(yoy_growth_energy_ly)
# Out:
#                       Nominal    Real
# Total Revenue         -16.41% -19.10%
# Pretax Income          -9.14% -12.06%
# Net Income              2.30%  -0.99%
# Tax Provision         -22.72% -25.21%
# Capital Expenditure   -14.57% -17.31%
# Purchase Of Business   22.38%  18.45%
# Cash Dividends Paid   -13.42% -16.20%

# %% [markdown]
# ## Fundamental analysis of AEX companies
# In this section I carry out fundamental analysis of companies from the AEX index using their annual financial reporting as made available by Yahoo-Finance with the help of the [yfinance](https://pypi.org/project/yfinance/) library. Specifically I look at:
# * the market capitalization of listed companies that are members of the S&P 500
# * their effective tax rate
# * their return on invested capital (ROIC), and its variant called recurring return on invested capital (Recurring ROIC)
# * their return on equity
# * their cost of equity
# * their after tax cost of debt
# * their weighted average cost of capital (WACC)
# * their enterprise value added (EVA)
# * their market value added (MVA)
#
# I calculate these metrics as follows:
# $$\text{Effective tax rate} = \frac{\text{Tax Provision}}{\text{Pretax Income}}$$
# $$\text{NOPAT} = \text{Net Income} + \text{Net Interest} \times (1 - \text{Effective tax rate})$$
# $$\text{Recurring NOPAT} = \text{NOPAT} + \text{Non recurring items} \times (1 - \text{Effective tax rate})$$
# $$\text{Invested Capital} = \text{Total Equity} + \text{Net Debt}$$
# $$\text{ROIC} = \frac{\text{NOPAT}}{\text{Invested Capital}}$$
# $$\text{Recurring ROIC} = \frac{\text{Recurring NOPAT}}{\text{Invested Capital}}$$
# $$\text{After Tax Cost of Debt} = \frac{\text{Interest Expense Non Operating}}{\text{Total Debt}} \times (1 - \text{Effective tax rate})$$
# $$\text{Cost of Equity} = \text{1-year risk-free rate} + \text{Company stock's } \beta \times \text{Expected market return}$$
# $$\text{ROE} = \frac{\text{Net Income}}{\text{Total Equity}}$$
# $$\text{EVA} = (\text{ROIC} - \text{WACC}) \times \text{Invested Capital}$$
# $$\text{MVA} = \text{Market Value of Equity} + \text{Market Value of Debt} - \text{Invested Capital}$$
#
# Important notes:
# * I use the average `Invested Capital` of the reporting year and the year before: 1) in the denominator when calculating `ROIC` and `Recurring ROIC`, and 2) when calculating `EVA`.
# * I use the average `Total Debt` of the reporting year and the year before in the denominator when calculating `After Tax Cost of Debt`.
# * I use the average `Total Equity` of the reporting year and the year before in the denominator when calculating `ROE`.
# * As the 1-Year risk-free rate I use Market Yield on U.S. Treasury Securities at 1-Year (it is a par yield).
# * As `Expected market return` over the risk-free rate I use the industry practice of taking it to be 5%.
# * For `Cost of Equity`, I calculate β using five years of monthly stock returns and their correlation with the S&P 500 index.
#
# The reason for selecting these metrics is that they effectively show how successful companies have been at creating shareholder value. They indicate whether the firm’s use of capital generates returns above its cost — for example, whether ROIC exceeds WACC when considering both equity and debt, or whether ROE exceeds the Cost of Equity when focusing on equity capital alone. When these conditions hold, the company is creating tangible value.
#
# All amounts are represented either in billions of euros or as percentage points. For companies that report their financials in currencies other than the euro, I convert EVA and MVA into euros using the exchange rate on the reporting date.
#
# **Notes**
# * For banks, ROIC is not a meaningful measure, because debt and customer deposits function as operating inputs rather than financing. I therefore exclude banks from the ROIC analysis.
# * Some data providers, such as [Morningstar](https://morningstar.com), do not subtract cash and cash equivalents when calculating Invested Capital. Instead, they use Total Equity + Total Debt. As a result, Morningstar reports ROIC values that are slightly lower than the corresponding ROIC measures calculated in this notebook.

# %%
cur_components = [component for component in aex_metrics.get_current_components()
                  if aex_metrics.tickers.tickers[component].info['sectorKey'] != 'financial-services']
aex_non_banks = set(cur_components) - set(aex_metrics.get_banking_sector_components())

# %%
fa_metrics = aex_metrics.calculate_financial_metrics(list(aex_non_banks), currency_conversion_df=cur_conv_df)\
    .dropna(thresh=2, subset=['ROE', 'Recurring ROE'])

# %%
pd.options.display.float_format = (lambda x: '{:.2%}'.format(x) if abs(x) < 5 else '€{:,.2f}bn'.format(x/1e9) if not pd.isna(x) else '<NA>')
pd.options.display.max_rows = 80
fa_metrics.iloc[:40,:10]
# Out:
#                Effective tax rate   ROIC Recurring ROIC     ROE Recurring ROE  \
# symbol   year
# AALB.AS  2022              24.09% 11.18%         11.18%  13.43%        13.43%
#          2023              24.41% 11.58%         11.58%  12.94%        12.94%
#          2024              28.36%  6.77%          6.01%   6.99%         6.10%
#          2025              29.31%  5.86%          4.68%   5.92%         4.47%
# AD.AS    2022              22.20% 16.80%         16.72%  16.53%        16.43%
#          2023              19.83% 13.98%         13.99%  12.43%        12.44%
#          2024              21.65% 13.75%         13.74%  11.68%        11.67%
#          2025              22.42% 16.86%         16.91%  15.27%        15.33%
# ADYEN.AS 2022              21.64% 23.74%         25.25%  23.35%        24.86%
#          2023              25.92% 25.22%         26.20%  25.09%        26.07%
#          2024              24.58% 25.61%         25.67%  25.06%        25.12%
# ...

# %%
def display_roic_wacc_scatter_chart(df: pd.DataFrame, ticker_to_name: dict[str, str], num_years=4) -> None:
    # Calculate num_years-year averages per ticker (use all available years if < num_years)
    averages = df.groupby(level='symbol').tail(num_years).groupby(level='symbol').mean()
    # Latest MVA for bubble size
    latest_mva = df.groupby(level='symbol').last()[['MVA']]
    
    # Combine both
    plot_data = averages.iloc[:,:9].join(latest_mva, how='inner')
    
    plt.figure(figsize=(12, 8))
    ax = sns.scatterplot(data=plot_data, x='WACC', y='ROIC', hue=plot_data.index, size='MVA', sizes=(40, 600), alpha=0.85, legend=False)
    plt.axline((0, 0), slope=1, color='gray', linestyle='--', alpha=0.7, label='ROIC = WACC')
    
    ax.xaxis.set_major_formatter(mtick.PercentFormatter(1, decimals=0))
    ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
    
    # === PROPERLY SCALED $1 TRILLION REFERENCE BUBBLE ===
    mva_min = plot_data['MVA'].min()
    mva_max = plot_data['MVA'].max()

    # Choose a nice round reference value just above the largest MVA (e.g. 500bn when max ≈ 400bn)
    round_to = 100e9 if mva_max > (mva_min + mva_max) / 2 > 100e9 else 10e9
    ref_mva = np.floor((mva_min + mva_max) / 2 / round_to) * round_to
    ref_size = 40 + (600 - 40) * (ref_mva - mva_min) / (mva_max - mva_min)

    # Convert seaborn area to matplotlib markersize (approximate)
    ref_markersize = np.sqrt(ref_size)               # markersize is roughly sqrt of area
    
    # Create custom legend handles
    from matplotlib.lines import Line2D
    legend_elements = [
        Line2D([0], [0], marker='o', color='w', label=f'€{ref_mva/1e9:.0f} Billion MVA',
               markerfacecolor='gray', markersize=ref_markersize, alpha=0.35),
        Line2D([0], [0], color='gray', linestyle='--', label='ROIC = WACC')]
    
    plt.legend(handles=legend_elements, loc='upper left')
    
    for ticker, row in averages.iterrows():
        ax.text(row['WACC'] + 0.001, row['ROIC'], ticker_to_name[ticker], fontsize=9, ha='left', va='center')
    plt.title(f'{num_years}-Year Average ROIC vs {num_years}-Year Average WACC\n(bubble size = Latest MVA)')
    plt.xlabel("Average WACC")
    plt.ylabel("Average ROIC")
    plt.tight_layout()
    plt.grid(True, alpha=0.3)

# %%
display_roic_wacc_scatter_chart(fa_metrics, ticker_to_name)
