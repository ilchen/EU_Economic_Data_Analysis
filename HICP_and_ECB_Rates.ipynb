# %% [markdown]
# # Eurozone consumer price inflation, ECB Deposit Facility rate, Market Yields on 10-Year Government Bonds, wage inflation, and Risk-free Yield Curve
# This notebook juxtaposes the evolution of Eurozone consumer prices inflation as measured by the HICP (Harmonized Index of Consumer Prices) with ECB Deposit Facility Rate and 10 year Government Bond yields. It then looks at the relationship between riskfree rates (e.g. 10-year AAA-rated eurozone central government bonds rates) and Eurozone HICP + real GDP growth rates. HICP + GDP growth rates is known as _the intrinsic riskfree rate_. In theory, the yield on a 10-year AAA-rated eurozone government bond&mdash;such as Germany’s bunds&mdash;should approximate the intrinsic risk-free rate. This notebook examines how this relationship has evolved since the 1990s.
#
# I then look at Euro Area wage inflation data.
#
# Finally, I look at the evolution of the Euro riskless rate curve as defined by the yields on AAA-rated eurozone central government bonds.
#
# **NB**: Throughout this notebook in datasets with a quarterly frequency, data indexed to the start of a quarter designates the whole quarter starting on that date.

# %%
# Uncomment if running in Google Colaboratory, otherwise the import of the curves module in the cell below will fail
#!git clone -l -s https://github.com/ilchen/US_Economic_Data_Analysis.git cloned-repo
#%cd cloned-repo

# Install the latest version of eurostat
# !pip install eurostat -U

# %%
import pandas as pd
import numpy as np
import matplotlib.ticker as mtick
import pandas_datareader.data as web
from pandas.tseries.offsets import MonthBegin, BDay, QuarterBegin

import eurostat
import sdmx

from datetime import date

from dateutil.relativedelta import relativedelta

from pricing import curves

# %%
report_start = date.fromisoformat('1996-01-01')
report_end = date.today()

# %% [markdown]
# ### Get Consumer Price Index for the Eurozone, ECB Deposit Facility Rate, 10 Year Government Bond Yields, and Real GDP
# I use the following dataseries provided by [FRED](https://fred.stlouisfed.org/):
# * `ECBDFR` &mdash; ECB Deposit Facility Rate for Euro Area (daily frequency, from 1999)
# * `ECBMLFR` &mdash; ECB Marginal Lending Facility Rate for Euro Area (daily frequency, from 1999). This is the rate at which banks can borrow money from the central bank against collateral for a period of one day (overnight). This rate is always higher than the main refinancing rate and therefore sets an upper limit for money market rates.
#
# And the following dataseries provided by the [Eurostat](https://ec.europa.eu/eurostat/web/main/data/database):
# * `irt_lt_mcby_m` &mdash; EMU convergence criterion series (monthly frequency). This series returns a dataset containing Long-Term Government Bond Yields for the Eurozone at 10-year maturity. These are par yields with an annual compounding frequency.
# * `prc_hicp_midx` &mdash; Harmonized Index of Consumer Prices: All Items for the Eurozone (monthly frequency, 2015=100, from 1996)
#
# There's a relationship between the riskless rate as represented by AAA-rated eurozone central government bonds rates on the one hand and real GDP growth and inflation rates on the other hand. I use 10-year Germany Bond Yields as proxy for riskless long-term rates in the Eurozone given Germany's AAA credit rating. At the end of this section I look at real GDP developments in conjunction with the inflation of consumer prices. To calculate GDP growth for the Euro area I make use of the following dataseries from [Eurostat](https://ec.europa.eu/eurostat/databrowser/view/NAMQ_10_GDP/default/table?lang=en):
# * `namq_10_gdp` — Real Gross Domestic Product for the Eurozone, Millions of Chained 2010 Euros (quarterly frequency, from 1996). The closest series published by the FRED is `CLVMEURSCAB1GQEA19`, however it is still based on the old configuration of the Eurozone (EA19) so I don't use it. I make use of both non seasonally adjusted as well as seasonally and calendar adjusted data. This is needed because I want to obtain both annual GDP growth (i.e. growth over four quarters) as well as quarterly GDP growth and express the latter at an annual rate. I use the following formula to translate quarterly changes into annual rates:
#
# $$\left(\left({\text{level of quarter n+1} \over \text{level of quarter n}}\right)^4-1\right)\times 100\% $$

# %%
ecbr = web.get_data_fred(['ECBDFR', 'ECBMLFR'], start=report_start, end=report_end)

# Retrieving the most recent Eurozone CPI and government bond yields from Eurostat's database
EUROSTAT_DE_COUNTRY_LABEL = 'DE'
EUROSTAT_IT_COUNTRY_LABEL = 'IT'
eu_irt_lt = eurostat.get_data_df('irt_lt_mcby_m',
        filter_pars={'startPeriod': report_start, 'geo': ['DE', 'IT']}).iloc[:, 2:]
eu_irt_lt = eu_irt_lt.set_index(eu_irt_lt.columns[0]).T
eu_irt_lt = eu_irt_lt.set_axis(pd.DatetimeIndex(eu_irt_lt.index, 'MS')).astype(ecbr.dtypes.iloc[0])

# Uncomment to provide data not yet delivered by the Eurostat, you can calculate it from e.g.
# https://www.investing.com/rates-bonds/germany-10-year-bond-yield-historical-data
# eu_irt_lt = pd.concat([eu_irt_lt, pd.DataFrame([[2.71, 3.56]], columns=eu_irt_lt.columns, index=pd.DatetimeIndex(['2025-08-01'], 'MS'))])

# Using Eurozone price index 2015=100, and All-items HICP: CP00 
eu_hicp = eurostat.get_data_df('prc_hicp_midx',
               filter_pars={'startPeriod': report_start, 'unit': 'I15', 'coicop': 'CP00', 'geo': 'EA'}).iloc[:, 3:]
eu_hicp = eu_hicp.set_index(eu_hicp.columns[0]).T
eu_hicp = eu_hicp.set_axis(pd.DatetimeIndex(eu_hicp.index, 'MS'))
# Since prc_hicp_midx is indexed to 2015=100, we need to convert it to annual percentage changes
eu_hicp_annual = eu_hicp.pct_change(12)

# Make frequencies explicit, resample to month srart
ecbr = ecbr.asfreq('D').resample('MS').last()

# Merge and truncate to start of celendar year 1999.
cpi_ecbr_irtlt = pd.concat([eu_hicp_annual, eu_irt_lt, ecbr], axis=1).loc['1997':]

cpi_ecbr_irtlt = cpi_ecbr_irtlt[['EA', 'ECBDFR', 'ECBMLFR', 'DE', 'IT']]

DE_YIELD_LABEL = '10y German Government Bond Yield'
IT_YIELD_LABEL = '10y Italian Government Bond Yield'
ECB_DEPOSIT_RATE_LABEL = 'ECB Deposit Facility Rate'
GRAPH_TITLE_HICP = 'Eurozone annual HICP, ECB Deposit Facility and Marginal Lending Rates, and 10y Government Bond Yields'
GRAPH_TITLE_HICP_2 = 'Eurozone HICP YoY (%), ECB Deposit Facility Rate, and German 10-Year Bond Yields'
cpi_ecbr_irtlt.rename(
    columns={'EA': 'Eurozone HICP, YoY Change',
             'ECBDFR': ECB_DEPOSIT_RATE_LABEL, 'ECBMLFR': 'ECB Marginal Lending Facility Rate',
             EUROSTAT_DE_COUNTRY_LABEL: DE_YIELD_LABEL,
             EUROSTAT_IT_COUNTRY_LABEL: IT_YIELD_LABEL},
    inplace=True)

# Querying for non seasonally adjusted, seasonally and calendar adjusted all-items Eurozone GDP data
# in chained linked volumes of 2010
real_gdp = eurostat.get_data_df('namq_10_gdp', filter_pars={
    'startPeriod': report_start, 'unit': 'CLV10_MEUR', 's_adj': ['NSA', 'SCA'], 'na_item': 'B1GQ', 'geo': 'EA'}).iloc[:, 4:]
real_gdp = real_gdp.set_index(real_gdp.columns[0]).T
real_gdp = real_gdp.set_axis(pd.DatetimeIndex(real_gdp.index, 'QS'))

# Seasonally adjusted data is in the second column, it is more suitable for extrapolating GDP quarterly growth
# at an annual rate
real_gdp_quarterly = ((real_gdp.iloc[:,1]/real_gdp.iloc[:,1].shift(1)).pow(4)-1)
real_gdp = real_gdp.iloc[:,:1]
real_gdp.rename(columns={'EA': 'Real GDP'}, inplace=True)

# To calculate the annual rate of GDP growth I sum up the non-seasonally adjusted GDP over the last 4 quarters.
# If Eurostat were publishing seasonally adjusted GDP data at annual volumes (as is the case in the US),
# I could calculate the mean over the past 4 quarters and use it as the actual annual GDP. 
real_gdp = real_gdp.rolling(4).sum().pct_change(4, fill_method=None)
real_gdp['Real GDP over quarter at annual rate'] = real_gdp_quarterly
real_gdp = real_gdp.loc['1997':]
real_gdp.columns.names = [None]

# %%
# Calculate the mean rate for the current month and, if needed, for the one before too
rmth_start = cpi_ecbr_irtlt.index[-2 if pd.isna(cpi_ecbr_irtlt.iloc[-2, -1]) else -1].date()

# Unfortunately Eurostat seems to have stopped the irt_lt_mcby_d dataset
# eu_irt_lt_cur_mth = eurostat.get_data_df('irt_lt_mcby_d',
#         filter_pars={'startPeriod': rmth_start - relativedelta(months=3), 'geo': ['DE', 'IT']}).iloc[:, 2:]
# eu_irt_lt_cur_mth = eu_irt_lt_cur_mth.set_index(eu_irt_lt_cur_mth.columns[0]).T
# eu_irt_lt_cur_mth = eu_irt_lt_cur_mth.set_axis(pd.DatetimeIndex(eu_irt_lt_cur_mth.index, 'B')).astype(ecbr.dtypes.iloc[0])
# eu_irt_lt_cur_mth.rename(
#     columns={EUROSTAT_DE_COUNTRY_LABEL: DE_YIELD_LABEL,
#              EUROSTAT_IT_COUNTRY_LABEL: IT_YIELD_LABEL},
#     inplace=True)
# eu_irt_lt_cur_mth = eu_irt_lt_cur_mth.asfreq('D').resample('MS').mean()
# if eu_irt_lt_cur_mth.index[-1].date() > rmth_start:
#     cpi_ecbr_irtlt.loc['2022':, [DE_YIELD_LABEL, IT_YIELD_LABEL]].update(eu_irt_lt_cur_mth.loc[rmth_start:])
#     cpi_ecbr_irtlt.update(eu_irt_lt_cur_mth)

# Convert to percentage points
cpi_ecbr_irtlt.iloc[:,[1,2,3,4]] /= 100

# %%
pd.options.display.float_format = '{:.4%}'.format
cpi_ecbr_irtlt.dropna(subset=[ECB_DEPOSIT_RATE_LABEL, DE_YIELD_LABEL, IT_YIELD_LABEL])
# Out:
#             Eurozone HICP, YoY Change  ECB Deposit Facility Rate  \
# 1999-01-01                    0.7650%                    2.0000%
# 1999-02-01                    0.7357%                    2.0000%
# 1999-03-01                    0.9393%                    2.0000%
# 1999-04-01                    1.0732%                    1.5000%
# 1999-05-01                    0.9355%                    1.5000%
# ...                               ...                        ...
# 2025-05-01                    1.8922%                    2.2500%
# 2025-06-01                    1.9908%                    2.0000%
# 2025-07-01                    2.0389%                    2.0000%
# 2025-08-01                    2.0439%                    2.0000%
# 2025-09-01                    2.2275%                    2.0000%
#
#             ECB Marginal Lending Facility Rate  \
# 1999-01-01                             4.5000%
# 1999-02-01                             4.5000%
# 1999-03-01                             4.5000%
# 1999-04-01                             3.5000%
# 1999-05-01                             3.5000%
# ...                                        ...
# 2025-05-01                             2.6500%
# 2025-06-01                             2.4000%
# 2025-07-01                             2.4000%
# 2025-08-01                             2.4000%
# 2025-09-01                             2.4000%
#
#             10y German Government Bond Yield  \
# 1999-01-01                           3.7000%
# 1999-02-01                           3.8500%
# 1999-03-01                           4.0400%
# 1999-04-01                           3.8500%
# 1999-05-01                           4.0100%
# ...                                      ...
# 2025-05-01                           2.5600%
# 2025-06-01                           2.5200%
# 2025-07-01                           2.6300%
# 2025-08-01                           2.6700%
# 2025-09-01                           2.6900%
#
#             10y Italian Government Bond Yield
# 1999-01-01                            3.9200%
# 1999-02-01                            4.0500%
# 1999-03-01                            4.2700%
# 1999-04-01                            4.1100%
# 1999-05-01                            4.2800%
# ...                                       ...
# 2025-05-01                            3.6300%
# 2025-06-01                            3.5000%
# 2025-07-01                            3.5400%
# 2025-08-01                            3.5400%
# 2025-09-01                            3.5600%
#
# [321 rows x 5 columns]

# %%
ax = cpi_ecbr_irtlt.iloc[:,:2].plot(figsize=(20,10), grid=True,
                        title=GRAPH_TITLE_HICP_2,
                        xticks=cpi_ecbr_irtlt.index[::12], xlabel='', rot=45, yticks=np.arange(0, .13, .02))
cpi_ecbr_irtlt.iloc[:,3:].plot(ax=ax, linestyle='--', grid=True,
                        xticks=cpi_ecbr_irtlt.index[::12], xlabel='', rot=45, yticks=np.arange(0, .13, .02))
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, cpi_ecbr_irtlt.index[::12])))

# %% [markdown]
# #### Eurozone HICP  based on monthly and quarterly changes
# In the previous part of this notebook I looked at HICP based on changes compared to 12 months ago. This is the standard way of determining annual percentage cahnges. Below I look at monthly changes in HICP and then translate them into annual percentage changes using the following simple formula for translating monthly HICP changes into annual percentage changes:
#
# $$\left(\left({\text{level of month n+1} \over \text{level of month n}}\right)^{12}-1\right)\times 100\% $$
#
# And then the same for translating quarterly changes into annual rates:
#
# $$\left(\left({\text{level of month n+1} \over \text{level of month n-2}}\right)^4-1\right)\times 100\% $$

# %%
from_date = date(2020, 1, 1)
eu_hicp_monthly = eu_hicp.pct_change().loc[from_date:, 'EA']
eu_hicp_monthly.rename('Eurozone HICP Change over Prev Month', inplace=True)
eu_hicp_annual = ((eu_hicp/eu_hicp.shift(1)).pow(12)-1).loc[from_date:, 'EA'].rename('Eurozone HICP Change over Prev Month at Annual Rate')
eu_hicp_quarterly = ((eu_hicp/eu_hicp.shift(3)).pow(4)-1).loc[from_date:, 'EA'].rename('Eurozone HICP Change over Prev 3 Months at Annual Rate')

# %%
eu_hicp_df = pd.concat([cpi_ecbr_irtlt.loc[from_date:, cpi_ecbr_irtlt.columns[0]], eu_hicp_quarterly, eu_hicp_annual], axis=1).dropna()

# %%
eu_hicp_df.tail(12)
# Out:
#             Eurozone HICP, YoY Change  \
# 2024-10-01                    1.9994%
# 2024-11-01                    2.2366%
# 2024-12-01                    2.4345%
# 2025-01-01                    2.5243%
# 2025-02-01                    2.3237%
# 2025-03-01                    2.1786%
# 2025-04-01                    2.1660%
# 2025-05-01                    1.8922%
# 2025-06-01                    1.9908%
# 2025-07-01                    2.0389%
# 2025-08-01                    2.0439%
# 2025-09-01                    2.2275%
#
#             Eurozone HICP Change over Prev 3 Months at Annual Rate  \
# 2024-10-01                                            1.5579%
# 2024-11-01                                           -0.3153%
# 2024-12-01                                            1.4933%
# 2025-01-01                                           -0.9726%
# 2025-02-01                                            2.0372%
# 2025-03-01                                            3.0886%
# 2025-04-01                                            6.6297%
# 2025-05-01                                            4.6036%
# 2025-06-01                                            3.3528%
# 2025-07-01                                            1.0917%
# 2025-08-01                                            1.9094%
# 2025-09-01                                            0.9952%
#
#             Eurozone HICP Change over Prev Month at Annual Rate
# 2024-10-01                                            4.1528%
# 2024-11-01                                           -3.8051%
# 2024-12-01                                            4.3491%
# 2025-01-01                                           -3.2556%
# 2025-02-01                                            5.2352%
# 2025-03-01                                            7.6081%
# 2025-04-01                                            7.0603%
# 2025-05-01                                           -0.6504%
# 2025-06-01                                            3.7940%
# 2025-07-01                                            0.1861%
# 2025-08-01                                            1.7802%
# 2025-09-01                                            1.0256%

# %%
import seaborn as sns
cm = sns.color_palette('Blues', as_cmap=True)
IDX_FORMAT = '{:%Y-%m}'

# %%
eu_hicp_df = eu_hicp_df.loc[from_date:, eu_hicp_df.columns[0:2]]
eu_hicp_df.tail(18).style.format_index(IDX_FORMAT).format('{:.2%}')\
    .set_properties(subset=eu_hicp_df.columns, **{'width': '200px'})\
    .set_table_styles([{'selector': 'th', 'props': 'text-align: right; width: 100px'}])\
    .background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_0feb0 th {
#   text-align: right;
#   width: 100px;
# }
# #T_0feb0_row0_col0 {
#   width: 200px;
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_0feb0_row0_col1, #T_0feb0_row3_col0 {
#   width: 200px;
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0feb0_row1_col0 {
#   width: 200px;
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_0feb0_row1_col1 {
#   width: 200px;
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_0feb0_row2_col0 {
#   width: 200px;
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_0feb0_row2_col1 {
#   width: 200px;
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_0feb0_row3_col1 {
#   width: 200px;
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_0feb0_row4_col0 {
#   width: 200px;
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_0feb0_row4_col1 {
#   width: 200px;
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_0feb0_row5_col0, #T_0feb0_row9_col1 {
#   width: 200px;
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0feb0_row5_col1 {
#   width: 200px;
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_0feb0_row6_col0 {
#   width: 200px;
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_0feb0_row6_col1 {
#   width: 200px;
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_0feb0_row7_col0 {
#   width: 200px;
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_0feb0_row7_col1 {
#   width: 200px;
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_0feb0_row8_col0 {
#   width: 200px;
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_0feb0_row8_col1 {
#   width: 200px;
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_0feb0_row9_col0 {
#   width: 200px;
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_0feb0_row10_col0 {
#   width: 200px;
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_0feb0_row10_col1 {
#   width: 200px;
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_0feb0_row11_col0 {
#   width: 200px;
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_0feb0_row11_col1 {
#   width: 200px;
#   background-color: #81badb;
#   color: #000000;
# }
# #T_0feb0_row12_col0 {
#   width: 200px;
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_0feb0_row12_col1 {
#   width: 200px;
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_0feb0_row13_col0 {
#   width: 200px;
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_0feb0_row13_col1 {
#   width: 200px;
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_0feb0_row14_col0 {
#   width: 200px;
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_0feb0_row14_col1 {
#   width: 200px;
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_0feb0_row15_col0 {
#   width: 200px;
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_0feb0_row15_col1 {
#   width: 200px;
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_0feb0_row16_col0 {
#   width: 200px;
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_0feb0_row16_col1 {
#   width: 200px;
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_0feb0_row17_col0 {
#   width: 200px;
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_0feb0_row17_col1 {
#   width: 200px;
#   background-color: #cddff1;
#   color: #000000;
# }
# </style>
# <table id="T_0feb0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0feb0_level0_col0" class="col_heading level0 col0" >Eurozone HICP, YoY Change</th>
#       <th id="T_0feb0_level0_col1" class="col_heading level0 col1" >Eurozone HICP Change over Prev 3 Months at Annual Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0feb0_level0_row0" class="row_heading level0 row0" >2024-04</th>
#       <td id="T_0feb0_row0_col0" class="data row0 col0" >2.37%</td>
#       <td id="T_0feb0_row0_col1" class="data row0 col1" >8.13%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row1" class="row_heading level0 row1" >2024-05</th>
#       <td id="T_0feb0_row1_col0" class="data row1 col0" >2.57%</td>
#       <td id="T_0feb0_row1_col1" class="data row1 col1" >6.39%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row2" class="row_heading level0 row2" >2024-06</th>
#       <td id="T_0feb0_row2_col0" class="data row2 col0" >2.52%</td>
#       <td id="T_0feb0_row2_col1" class="data row2 col1" >4.12%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row3" class="row_heading level0 row3" >2024-07</th>
#       <td id="T_0feb0_row3_col0" class="data row3 col0" >2.58%</td>
#       <td id="T_0feb0_row3_col1" class="data row3 col1" >1.60%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row4" class="row_heading level0 row4" >2024-08</th>
#       <td id="T_0feb0_row4_col0" class="data row4 col0" >2.17%</td>
#       <td id="T_0feb0_row4_col1" class="data row4 col1" >1.30%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row5" class="row_heading level0 row5" >2024-09</th>
#       <td id="T_0feb0_row5_col0" class="data row5 col0" >1.74%</td>
#       <td id="T_0feb0_row5_col1" class="data row5 col1" >0.06%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row6" class="row_heading level0 row6" >2024-10</th>
#       <td id="T_0feb0_row6_col0" class="data row6 col0" >2.00%</td>
#       <td id="T_0feb0_row6_col1" class="data row6 col1" >1.56%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row7" class="row_heading level0 row7" >2024-11</th>
#       <td id="T_0feb0_row7_col0" class="data row7 col0" >2.24%</td>
#       <td id="T_0feb0_row7_col1" class="data row7 col1" >-0.32%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row8" class="row_heading level0 row8" >2024-12</th>
#       <td id="T_0feb0_row8_col0" class="data row8 col0" >2.43%</td>
#       <td id="T_0feb0_row8_col1" class="data row8 col1" >1.49%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row9" class="row_heading level0 row9" >2025-01</th>
#       <td id="T_0feb0_row9_col0" class="data row9 col0" >2.52%</td>
#       <td id="T_0feb0_row9_col1" class="data row9 col1" >-0.97%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row10" class="row_heading level0 row10" >2025-02</th>
#       <td id="T_0feb0_row10_col0" class="data row10 col0" >2.32%</td>
#       <td id="T_0feb0_row10_col1" class="data row10 col1" >2.04%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row11" class="row_heading level0 row11" >2025-03</th>
#       <td id="T_0feb0_row11_col0" class="data row11 col0" >2.18%</td>
#       <td id="T_0feb0_row11_col1" class="data row11 col1" >3.09%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row12" class="row_heading level0 row12" >2025-04</th>
#       <td id="T_0feb0_row12_col0" class="data row12 col0" >2.17%</td>
#       <td id="T_0feb0_row12_col1" class="data row12 col1" >6.63%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row13" class="row_heading level0 row13" >2025-05</th>
#       <td id="T_0feb0_row13_col0" class="data row13 col0" >1.89%</td>
#       <td id="T_0feb0_row13_col1" class="data row13 col1" >4.60%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row14" class="row_heading level0 row14" >2025-06</th>
#       <td id="T_0feb0_row14_col0" class="data row14 col0" >1.99%</td>
#       <td id="T_0feb0_row14_col1" class="data row14 col1" >3.35%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row15" class="row_heading level0 row15" >2025-07</th>
#       <td id="T_0feb0_row15_col0" class="data row15 col0" >2.04%</td>
#       <td id="T_0feb0_row15_col1" class="data row15 col1" >1.09%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row16" class="row_heading level0 row16" >2025-08</th>
#       <td id="T_0feb0_row16_col0" class="data row16 col0" >2.04%</td>
#       <td id="T_0feb0_row16_col1" class="data row16 col1" >1.91%</td>
#     </tr>
#     <tr>
#       <th id="T_0feb0_level0_row17" class="row_heading level0 row17" >2025-09</th>
#       <td id="T_0feb0_row17_col0" class="data row17 col0" >2.23%</td>
#       <td id="T_0feb0_row17_col1" class="data row17 col1" >1.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Eurozone Real GDP growth
# I present both growth over the last 4 quarters as well as growth over one quarter, both expressed as annual percentage rates. For growth over one quarter (the 2<sup>nd</sup> column) I use seasonally and calendar adjusted data (Eurostat code `SCA`). For growth over the last 4 quarters (which provides the official annual growth) I use unadjusted data (Eurostat code `NSA`). Unfortunately Eurostat tends to delay publishing unadjusted data, as a result you might occasionally see a NaN value in the last row for it.

# %%
# real_gdp.loc['2020':]
real_gdp.tail(18).style.format_index(IDX_FORMAT).format('{:.2%}')\
    .set_properties(subset=real_gdp.columns, **{'width': '200px'})\
    .set_table_styles([{'selector': 'th', 'props': 'text-align: right; width: 100px'}])\
    .background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_24889 th {
#   text-align: right;
#   width: 100px;
# }
# #T_24889_row0_col0, #T_24889_row7_col1, #T_24889_row10_col1 {
#   width: 200px;
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_24889_row0_col1 {
#   width: 200px;
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_24889_row1_col0 {
#   width: 200px;
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_24889_row1_col1, #T_24889_row4_col0 {
#   width: 200px;
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_24889_row2_col0 {
#   width: 200px;
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_24889_row2_col1 {
#   width: 200px;
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_24889_row3_col0 {
#   width: 200px;
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_24889_row3_col1 {
#   width: 200px;
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_24889_row4_col1 {
#   width: 200px;
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_24889_row5_col0 {
#   width: 200px;
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_24889_row5_col1 {
#   width: 200px;
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_24889_row6_col0 {
#   width: 200px;
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_24889_row6_col1 {
#   width: 200px;
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_24889_row7_col0 {
#   width: 200px;
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_24889_row8_col0 {
#   width: 200px;
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_24889_row8_col1 {
#   width: 200px;
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_24889_row9_col0 {
#   width: 200px;
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_24889_row9_col1, #T_24889_row13_col1 {
#   width: 200px;
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_24889_row10_col0 {
#   width: 200px;
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_24889_row11_col0 {
#   width: 200px;
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_24889_row11_col1 {
#   width: 200px;
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_24889_row12_col0, #T_24889_row13_col0 {
#   width: 200px;
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_24889_row12_col1 {
#   width: 200px;
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_24889_row14_col0 {
#   width: 200px;
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_24889_row14_col1 {
#   width: 200px;
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_24889_row15_col0 {
#   width: 200px;
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_24889_row15_col1 {
#   width: 200px;
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_24889_row16_col0 {
#   width: 200px;
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_24889_row16_col1 {
#   width: 200px;
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_24889_row17_col0 {
#   width: 200px;
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_24889_row17_col1 {
#   width: 200px;
#   background-color: #e9f2fa;
#   color: #000000;
# }
# </style>
# <table id="T_24889">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24889_level0_col0" class="col_heading level0 col0" >Real GDP</th>
#       <th id="T_24889_level0_col1" class="col_heading level0 col1" >Real GDP over quarter at annual rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24889_level0_row0" class="row_heading level0 row0" >2021-01</th>
#       <td id="T_24889_row0_col0" class="data row0 col0" >-5.33%</td>
#       <td id="T_24889_row0_col1" class="data row0 col1" >3.09%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row1" class="row_heading level0 row1" >2021-04</th>
#       <td id="T_24889_row1_col0" class="data row1 col0" >1.59%</td>
#       <td id="T_24889_row1_col1" class="data row1 col1" >8.97%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row2" class="row_heading level0 row2" >2021-07</th>
#       <td id="T_24889_row2_col0" class="data row2 col0" >3.97%</td>
#       <td id="T_24889_row2_col1" class="data row2 col1" >7.35%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row3" class="row_heading level0 row3" >2021-10</th>
#       <td id="T_24889_row3_col0" class="data row3 col0" >6.37%</td>
#       <td id="T_24889_row3_col1" class="data row3 col1" >3.14%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row4" class="row_heading level0 row4" >2022-01</th>
#       <td id="T_24889_row4_col0" class="data row4 col0" >7.76%</td>
#       <td id="T_24889_row4_col1" class="data row4 col1" >2.87%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row5" class="row_heading level0 row5" >2022-04</th>
#       <td id="T_24889_row5_col0" class="data row5 col0" >5.19%</td>
#       <td id="T_24889_row5_col1" class="data row5 col1" >3.78%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row6" class="row_heading level0 row6" >2022-07</th>
#       <td id="T_24889_row6_col0" class="data row6 col0" >4.60%</td>
#       <td id="T_24889_row6_col1" class="data row6 col1" >1.86%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row7" class="row_heading level0 row7" >2022-10</th>
#       <td id="T_24889_row7_col0" class="data row7 col0" >3.61%</td>
#       <td id="T_24889_row7_col1" class="data row7 col1" >-0.16%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row8" class="row_heading level0 row8" >2023-01</th>
#       <td id="T_24889_row8_col0" class="data row8 col0" >2.74%</td>
#       <td id="T_24889_row8_col1" class="data row8 col1" >1.80%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row9" class="row_heading level0 row9" >2023-04</th>
#       <td id="T_24889_row9_col0" class="data row9 col0" >1.85%</td>
#       <td id="T_24889_row9_col1" class="data row9 col1" >0.81%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row10" class="row_heading level0 row10" >2023-07</th>
#       <td id="T_24889_row10_col0" class="data row10 col0" >1.23%</td>
#       <td id="T_24889_row10_col1" class="data row10 col1" >-0.17%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row11" class="row_heading level0 row11" >2023-10</th>
#       <td id="T_24889_row11_col0" class="data row11 col0" >0.92%</td>
#       <td id="T_24889_row11_col1" class="data row11 col1" >0.20%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row12" class="row_heading level0 row12" >2024-01</th>
#       <td id="T_24889_row12_col0" class="data row12 col0" >0.48%</td>
#       <td id="T_24889_row12_col1" class="data row12 col1" >1.12%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row13" class="row_heading level0 row13" >2024-04</th>
#       <td id="T_24889_row13_col0" class="data row13 col0" >0.45%</td>
#       <td id="T_24889_row13_col1" class="data row13 col1" >0.81%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row14" class="row_heading level0 row14" >2024-07</th>
#       <td id="T_24889_row14_col0" class="data row14 col0" >0.66%</td>
#       <td id="T_24889_row14_col1" class="data row14 col1" >1.64%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row15" class="row_heading level0 row15" >2024-10</th>
#       <td id="T_24889_row15_col0" class="data row15 col0" >0.85%</td>
#       <td id="T_24889_row15_col1" class="data row15 col1" >1.61%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row16" class="row_heading level0 row16" >2025-01</th>
#       <td id="T_24889_row16_col0" class="data row16 col0" >1.12%</td>
#       <td id="T_24889_row16_col1" class="data row16 col1" >2.26%</td>
#     </tr>
#     <tr>
#       <th id="T_24889_level0_row17" class="row_heading level0 row17" >2025-04</th>
#       <td id="T_24889_row17_col0" class="data row17 col0" >1.28%</td>
#       <td id="T_24889_row17_col1" class="data row17 col1" >0.48%</td>
#     </tr>
#   </tbody>
# </table>

# %%
ax = real_gdp.iloc[:,0].plot(figsize=(20,10), grid=True, title='Eurozone Real GDP growth (annual rate)',
                   xticks=real_gdp.index[::4], xlabel='', rot=45)#, yticks=np.arange(-.15, .2, 0.025))
ax.axhline(y=0, lw=2, c='k')
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
ax2 = ax.twiny()
real_gdp.iloc[:,0].plot.bar(ax=ax2, xlabel='', legend=False)
ax.axhline(y=real_gdp.iloc[:,0].mean(), ls='--', c='#1f77b4', label='Mean level of Real GDP growth')
ax.legend()
ax2.xaxis.set_major_locator(mtick.NullLocator())
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, real_gdp.index[::4])))

# %%
print(f'Mean level of annual rate of real GDP growth in the Euro area since {real_gdp.index[0]:%Y-%m-%d}: '
      f'{real_gdp.iloc[:,0].mean():.2%}')
# Out:
# Mean level of annual rate of real GDP growth in the Euro area since 1997-01-01: 1.64%

# %%
# Including only the yield on German government bonds as those of Italy are not AAA rated and cannot be regarded
# as riskfree
df = pd.concat([real_gdp.iloc[:,0], cpi_ecbr_irtlt.iloc[:,[0,3]].resample('QS').mean()], axis=1)\
    .loc[:real_gdp.last_valid_index()] # Truncate based on last valid GDP value
df.loc['2020':]
# Out:
#             Real GDP  Eurozone HICP, YoY Change  \
# 2020-01-01   0.5078%                    1.1090%
# 2020-04-01  -3.3836%                    0.2217%
# 2020-07-01  -4.9092%                   -0.0313%
# 2020-10-01  -6.0136%                   -0.2754%
# 2021-01-01  -5.3281%                    1.0597%
# 2021-04-01   1.5899%                    1.8360%
# 2021-07-01   3.9700%                    2.8279%
# 2021-10-01   6.3745%                    4.6274%
# 2022-01-01   7.7590%                    6.1422%
# 2022-04-01   5.1851%                    8.0453%
# 2022-07-01   4.6008%                    9.3113%
# 2022-10-01   3.6131%                    9.9572%
# 2023-01-01   2.7385%                    8.0105%
# 2023-04-01   1.8484%                    6.1931%
# 2023-07-01   1.2311%                    4.9630%
# 2023-10-01   0.9157%                    2.7423%
# 2024-01-01   0.4753%                    2.5927%
# 2024-04-01   0.4525%                    2.4855%
# 2024-07-01   0.6563%                    2.1635%
# 2024-10-01   0.8508%                    2.2235%
# 2025-01-01   1.1233%                    2.3422%
# 2025-04-01   1.2803%                    2.0163%
#
#             10y German Government Bond Yield
# 2020-01-01                          -0.4400%
# 2020-04-01                          -0.4667%
# 2020-07-01                          -0.5200%
# 2020-10-01                          -0.6133%
# 2021-01-01                          -0.4633%
# 2021-04-01                          -0.2800%
# 2021-07-01                          -0.4500%
# 2021-10-01                          -0.3000%
# 2022-01-01                           0.1033%
# 2022-04-01                           1.0500%
# 2022-07-01                           1.3033%
# 2022-10-01                           2.1167%
# 2023-01-01                           2.3133%
# 2023-04-01                           2.3600%
# 2023-07-01                           2.5567%
# 2023-10-01                           2.5067%
# 2024-01-01                           2.2867%
# 2024-04-01                           2.4833%
# 2024-07-01                           2.2800%
# 2024-10-01                           2.2400%
# 2025-01-01                           2.5433%
# 2025-04-01                           2.5300%

# %% [markdown]
# ### Visualizing the relationship between 10y German Bund Yield and the Intrinsic Riskfree rate (real GDP growth + inflation rates)
# I use Germany 10-year government bond yield as a representative of a Eurozone central government bond with an AAA credit rating in the below graph. It is a proxy for the actual long-term riskfree rate in the Eurozone. I compare it with the intrinsic riskfree rate as defined by the sum of real GDP growth and inflation rates.

# %%
ax = df.iloc[:, -1].plot(figsize=(20,10), grid=True,
                         title='Annual HICP and Real GDP vs ' + DE_YIELD_LABEL,
                         xticks=df.index[::2], xlabel='', rot=45,
                         yticks=np.arange(-.15, .2, 0.025), linestyle='--', color='k')
ax2 = ax.twiny()
df.iloc[:,[0,1]].plot.bar(ax=ax2, xlabel='', stacked=True)
ax.legend(loc='upper center')
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
ax2.xaxis.set_major_locator(mtick.NullLocator())
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, df.index[::2])))

# %%
print('Gap between intrinsic (GDP+HICP) and actual (10-y German Bund) riskfree rates: {:.2%}\n'
      'Compared with: {:.2%} one quarter earlier'.format(
    df.iloc[-1,0] + df.iloc[-1,1] - df.iloc[-1,2], df.iloc[-2,0] + df.iloc[-2,1] - df.iloc[-2,2]))
# Out:
# Gap between intrinsic (GDP+HICP) and actual (10-y German Bund) riskfree rates: 0.77%
# Compared with: 0.92% one quarter earlier

# %%
print('Average gap between intrinsic (GDP+HICP) and actual (10-y German Bund) riskfree rates since {:%Y-%m}: {:.2%}'
      .format(df.index[0], df.iloc[:,0].mean() + df.iloc[:,1].mean() - df.iloc[:,2].mean()))
# Out:
# Average gap between intrinsic (GDP+HICP) and actual (10-y German Bund) riskfree rates since 1997-01: 1.12%

# %%
from_dt = date(2009, 1, 1)
means = df.loc[from_dt:].mean()
print('Average gap between intrinsic (GDP+HICP) and actual (10-y German Bund) riskfree rates since {:%Y-%m}: {:.2%}'
      .format(from_dt, means.iloc[0] + means.iloc[1] - means.iloc[2]))
# Out:
# Average gap between intrinsic (GDP+HICP) and actual (10-y German Bund) riskfree rates since 2009-01: 1.85%

# %% [markdown]
# ## A quick look at wage inflation in the Eurozone
# In contrast to U.S. Bureau of Labor Statistics, unfortunately Eurostat typically lags by one quarter in publishing data on wage inflation and publishes them only with quarterly frequencies.
#
# I use the following dataseries provided by [Eurostat](https://ec.europa.eu/eurostat/web/main/data/database):
# * `lc_lci_r2_q` &mdash; Labour cost index by NACE Rev. 2 activity - nominal value, quarterly data. This series returns a MultiIndexed dataset containing different views on this data for the Eurozone as a whole as whell as for each individual country in the EU.

# %%
# Seasonally and calendar-adjusted, 2020=100
# NACE Rev 2. Sections B to S from 2009Q1 onward
# Labour cost for LCI (compensation of employees plus taxes minus subsidies): D1_D4_MD5
eu_wagei = eurostat.get_data_df('lc_lci_r2_q',
        filter_pars={'startPeriod': report_start, 's_adj': 'SCA', 'unit': 'I20',
                     'nace_r2': 'B-S', 'lcstruct': 'D1_D4_MD5', 'geo': ['EA', 'EA20']}).iloc[:, 5:]
eu_wagei = eu_wagei.set_index(eu_wagei.columns[0]).T
eu_wagei = eu_wagei.set_axis(pd.DatetimeIndex(eu_wagei.index, 'QS'))
eu_wagei.EA = eu_wagei.EA.combine_first(eu_wagei.EA20)
eu_wagei = eu_wagei.iloc[:, :1]
eu_wagei.dropna(inplace=True)
eu_wagei_quarterly = (eu_wagei/eu_wagei.shift()).pow(4) - 1
eu_wagei_quarterly.rename(columns={'EA': 'Hourly Earnings Change Over Last Quarter at Annual Rate'}, inplace=True)
eu_wagei = eu_wagei.pct_change(4, fill_method=None).dropna()
eu_wagei.rename(columns={'EA': 'Hourly Earnings, YoY Change'}, inplace=True)

cpi_and_wagei = pd.concat([cpi_ecbr_irtlt.iloc[:,0].resample('QS').last().loc[eu_wagei.index[0]:], eu_wagei], axis=1)\
     .loc[:date.today()-relativedelta(months=+3)]

# %%
# Mean level of Wage Inflation, and HICP
mean_level_wagei = eu_wagei.iloc[:,0].mean()
mean_level_cpi = cpi_ecbr_irtlt.iloc[:,0].mean()

LABEL_MEAN_WAGEI = 'Mean Level of Annual Changes in Labour Costs'
LABEL_MEAN_CPI = 'Mean Level of Annual Changes in HICP'

# %%
ax = cpi_and_wagei.plot(figsize=(20,10), grid=True,
                        title='Eurozone Annual HICP and Hourly Earnings',
                        xticks=cpi_and_wagei.index[::2], xlabel='', rot=45, yticks=np.arange(0, .13, .02))
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
#ax.axhline(y=mean_level_cpi, lw=2, ls='--', c='#1f77b4', label=LABEL_MEAN_CPI)
ax.axhline(y=mean_level_wagei, lw=2, ls='--', c='#ff7f0e', label=LABEL_MEAN_WAGEI)
ax.legend()
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, cpi_and_wagei.index[::2])))

# %%
print('Labour costs annual growth {:+.2%} above the historic mean of {:.2%} in quarter starting on {:%Y-%m-%d}'
      .format(eu_wagei.iloc[-1,0]-mean_level_wagei, mean_level_wagei, eu_wagei.index[-1]))
# Out:
# Labour costs annual growth +1.03% above the historic mean of 2.44% in quarter starting on 2025-04-01

# %%
cpi_and_wagei = cpi_and_wagei.loc[from_date:, cpi_and_wagei.columns[0:2]]
cpi_and_wagei.tail(18).style.format_index(IDX_FORMAT).format('{:.2%}')\
    .set_properties(subset=cpi_and_wagei.columns, **{'width': '200px'})\
    .set_table_styles([{'selector': 'th', 'props': 'text-align: right; width: 100px'}])\
    .background_gradient(cmap=cm, subset=cpi_and_wagei.columns)
# Out:
# <style type="text/css">
# #T_d6445 th {
#   text-align: right;
#   width: 100px;
# }
# #T_d6445_row0_col0 {
#   width: 200px;
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_d6445_row0_col1, #T_d6445_row13_col0 {
#   width: 200px;
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d6445_row1_col0 {
#   width: 200px;
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_d6445_row1_col1 {
#   width: 200px;
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_d6445_row2_col0 {
#   width: 200px;
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_d6445_row2_col1 {
#   width: 200px;
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_d6445_row3_col0, #T_d6445_row3_col1 {
#   width: 200px;
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_d6445_row4_col0 {
#   width: 200px;
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_d6445_row4_col1 {
#   width: 200px;
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_d6445_row5_col0, #T_d6445_row6_col1 {
#   width: 200px;
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d6445_row5_col1, #T_d6445_row15_col1 {
#   width: 200px;
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_d6445_row6_col0 {
#   width: 200px;
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_d6445_row7_col0 {
#   width: 200px;
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_d6445_row7_col1 {
#   width: 200px;
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_d6445_row8_col0 {
#   width: 200px;
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_d6445_row8_col1 {
#   width: 200px;
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_d6445_row9_col0 {
#   width: 200px;
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_d6445_row9_col1 {
#   width: 200px;
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_d6445_row10_col0 {
#   width: 200px;
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_d6445_row10_col1 {
#   width: 200px;
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_d6445_row11_col0, #T_d6445_row14_col0 {
#   width: 200px;
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_d6445_row11_col1 {
#   width: 200px;
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_d6445_row12_col0 {
#   width: 200px;
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_d6445_row12_col1 {
#   width: 200px;
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_d6445_row13_col1 {
#   width: 200px;
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_d6445_row14_col1 {
#   width: 200px;
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_d6445_row15_col0 {
#   width: 200px;
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_d6445_row16_col0 {
#   width: 200px;
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_d6445_row16_col1 {
#   width: 200px;
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_d6445_row17_col0 {
#   width: 200px;
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_d6445_row17_col1 {
#   width: 200px;
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d6445">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6445_level0_col0" class="col_heading level0 col0" >Eurozone HICP, YoY Change</th>
#       <th id="T_d6445_level0_col1" class="col_heading level0 col1" >Hourly Earnings, YoY Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6445_level0_row0" class="row_heading level0 row0" >2021-04</th>
#       <td id="T_d6445_row0_col0" class="data row0 col0" >1.90%</td>
#       <td id="T_d6445_row0_col1" class="data row0 col1" >-0.10%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row1" class="row_heading level0 row1" >2021-07</th>
#       <td id="T_d6445_row1_col0" class="data row1 col0" >3.36%</td>
#       <td id="T_d6445_row1_col1" class="data row1 col1" >2.10%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row2" class="row_heading level0 row2" >2021-10</th>
#       <td id="T_d6445_row2_col0" class="data row2 col0" >4.96%</td>
#       <td id="T_d6445_row2_col1" class="data row2 col1" >2.59%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row3" class="row_heading level0 row3" >2022-01</th>
#       <td id="T_d6445_row3_col0" class="data row3 col0" >7.44%</td>
#       <td id="T_d6445_row3_col1" class="data row3 col1" >3.70%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row4" class="row_heading level0 row4" >2022-04</th>
#       <td id="T_d6445_row4_col0" class="data row4 col0" >8.64%</td>
#       <td id="T_d6445_row4_col1" class="data row4 col1" >5.32%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row5" class="row_heading level0 row5" >2022-07</th>
#       <td id="T_d6445_row5_col0" class="data row5 col0" >9.93%</td>
#       <td id="T_d6445_row5_col1" class="data row5 col1" >3.42%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row6" class="row_heading level0 row6" >2022-10</th>
#       <td id="T_d6445_row6_col0" class="data row6 col0" >9.20%</td>
#       <td id="T_d6445_row6_col1" class="data row6 col1" >5.35%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row7" class="row_heading level0 row7" >2023-01</th>
#       <td id="T_d6445_row7_col0" class="data row7 col0" >6.88%</td>
#       <td id="T_d6445_row7_col1" class="data row7 col1" >5.01%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row8" class="row_heading level0 row8" >2023-04</th>
#       <td id="T_d6445_row8_col0" class="data row8 col0" >5.52%</td>
#       <td id="T_d6445_row8_col1" class="data row8 col1" >4.67%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row9" class="row_heading level0 row9" >2023-07</th>
#       <td id="T_d6445_row9_col0" class="data row9 col0" >4.34%</td>
#       <td id="T_d6445_row9_col1" class="data row9 col1" >5.20%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row10" class="row_heading level0 row10" >2023-10</th>
#       <td id="T_d6445_row10_col0" class="data row10 col0" >2.93%</td>
#       <td id="T_d6445_row10_col1" class="data row10 col1" >4.16%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row11" class="row_heading level0 row11" >2024-01</th>
#       <td id="T_d6445_row11_col0" class="data row11 col0" >2.43%</td>
#       <td id="T_d6445_row11_col1" class="data row11 col1" >4.77%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row12" class="row_heading level0 row12" >2024-04</th>
#       <td id="T_d6445_row12_col0" class="data row12 col0" >2.52%</td>
#       <td id="T_d6445_row12_col1" class="data row12 col1" >4.91%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row13" class="row_heading level0 row13" >2024-07</th>
#       <td id="T_d6445_row13_col0" class="data row13 col0" >1.74%</td>
#       <td id="T_d6445_row13_col1" class="data row13 col1" >4.68%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row14" class="row_heading level0 row14" >2024-10</th>
#       <td id="T_d6445_row14_col0" class="data row14 col0" >2.43%</td>
#       <td id="T_d6445_row14_col1" class="data row14 col1" >3.99%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row15" class="row_heading level0 row15" >2025-01</th>
#       <td id="T_d6445_row15_col0" class="data row15 col0" >2.18%</td>
#       <td id="T_d6445_row15_col1" class="data row15 col1" >3.42%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row16" class="row_heading level0 row16" >2025-04</th>
#       <td id="T_d6445_row16_col0" class="data row16 col0" >1.99%</td>
#       <td id="T_d6445_row16_col1" class="data row16 col1" >3.47%</td>
#     </tr>
#     <tr>
#       <th id="T_d6445_level0_row17" class="row_heading level0 row17" >2025-07</th>
#       <td id="T_d6445_row17_col0" class="data row17 col0" >2.23%</td>
#       <td id="T_d6445_row17_col1" class="data row17 col1" >nan%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Analyzing Euro Riskless Rate Curve
# In this analysis I make use of the spot rates (aka zero-rates) implied by AAA-rated governmental bonds in the Euro area.
#
# I use the following dataseries provided by the [Eurostat](https://ec.europa.eu/eurostat/web/main/data/database):
# * `irt_euryld_m` &mdash; Euro yield curves (monthly frequency). This series returns a MultiIndexed dataset from which multiple yields can be extraced: Instantaneous forward yield curve, Par yield curve, and Spot rate yield curve. In my analysis I use the Spor rate yield curve. The returned rates are presented using Annual percentage rates/yields and represent the average over all business days in a given month. [The ECB uses continuous compounding](https://www.ecb.europa.eu/stats/financial_markets_and_interest_rates/euro_area_yield_curves/shared/pdf/technical_notes.pdf) when calculating them.
# * `irt_st_m` &mdash; Euro EURIBOR rates (monthly frequency). EURIBOR uses the actual/360 daycount convention. This series returns a MultiIndexed dataset allowing to select different maturities. I only use the 1 month rates in this notebook as the spread between government bond rates and EURIBOR tends to increase with longer maturities. Rates returned represent the average over all business days in a given month.
#
# And the following dataseries provided by the [ECB](https://data.ecb.europa.eu/data/data-categories):
# * `ECBDFR` (`FM.B.U2.EUR.4F.KR.DFR.LEV`) &mdash; ECB Deposit Facility Rate (DFR) for Euro Area (daily frequency). I use the lower of the ECB Deposit Facility Rate and €STR as a proxy for the riskfree overnight rate.
# * `EST.B.EU000A2X2A25.WT` &mdash; €STR, Euro short-term rate - Volume-weighted trimmed mean rate (daily frequency). I use the lower of €STR and the DFR as a proxy for the riskfree overnight rate.

# %%
# The ECB provides yields for maturities ranging from 3 months till 30 years
year_maturities = range(1, 31)
maturities = ['Y'+str(maturity) for maturity in year_maturities]

# Taking the last 3 months and converting to decimal fractions
euro_curves = eurostat.get_data_df('irt_euryld_m', filter_pars={
    'startPeriod': (MonthBegin().rollback(report_end)-MonthBegin(4)).date(), 'freq': 'M',
    'yld_curv': 'SPOT_RT',
    'maturity': maturities,
    'bonds': 'CGB_EA_AAA', 'geo': 'EA'})
euro_curves = euro_curves.drop(euro_curves.columns[:3].append(euro_curves.columns[4:5]), axis=1)
euro_curves = euro_curves.set_index(euro_curves.columns[0]).T / 100.
euro_spot_rates = euro_curves.set_axis(pd.DatetimeIndex(euro_curves.index, 'MS'))

mm_rates = eurostat.get_data_df('irt_st_m', filter_pars={
    'startPeriod': (MonthBegin().rollback(report_end)-MonthBegin(4)).date(), 'freq': 'M',
    'int_rt': 'IRT_M1', 'geo': 'EA'}).iloc[:,2:]
mm_rates = mm_rates.set_index(mm_rates.columns[0]).T / 100.
mm_rates = mm_rates.set_axis(pd.DatetimeIndex(mm_rates.index, 'MS'))

ecb_deposit_rate = web.get_data_fred('ECBDFR', start=MonthBegin().rollback(report_end)-MonthBegin(4)) / 100.

# The €STR rate
ecb = sdmx.Client('ECB')
data_msg = ecb.data('EST', key='B.EU000A2X2A25.WT', params={'startPeriod': (MonthBegin().rollback(report_end)-MonthBegin(4)).date()})
overnight_rate = sdmx.to_pandas(data_msg.data[0]).loc['B', 'EU000A2X2A25', 'WT'] / 100.
overnight_rate = overnight_rate.set_axis(pd.DatetimeIndex(overnight_rate.index)).loc[euro_spot_rates.index[0]:]

# Resample to monthly frequency
ecb_deposit_rate = ecb_deposit_rate.asfreq('D').resample('MS').mean()
overnight_rate = overnight_rate.resample('MS').mean()

# Using a minimum of the €STR and DFR rates
overnight_rate = pd.concat([overnight_rate, ecb_deposit_rate], axis=1).min(axis=1)

# %%
# Converting EURIBOR and ECB Deposit rates from actual/360 to actual/actual and then to continuous compounding
leap_year_cond = lambda idx: idx.year % 4 == 0 & ((idx.year % 100 != 0) | (idx.year % 400 == 0))
mm_rates[leap_year_cond(mm_rates.index)] *= 366. / 360
mm_rates[np.invert(leap_year_cond(mm_rates.index))] *= 365. / 360
overnight_rate[leap_year_cond(overnight_rate.index)] *= 366. / 360
overnight_rate[np.invert(leap_year_cond(overnight_rate.index))] *= 365. / 360

# From annual to continuous compounding
overnight_rate = np.log(1 + overnight_rate)
mm_rates = np.log(1 + mm_rates)

# %%
mm_rates.columns.rename(euro_spot_rates.columns.name, inplace=True)
mm_rates.rename(columns={'EA': '1 month'}, inplace=True)

# 'mm_rates' may have an additional month of data not yet present in 'euro_spot_rates'
if len(mm_rates.index.intersection(euro_spot_rates.index)) == min(len(mm_rates.index), len(euro_spot_rates.index)):
    if not mm_rates.index.difference(euro_spot_rates.index).empty:
        mm_rates = mm_rates.loc[euro_spot_rates.index]
pd.concat([mm_rates, euro_spot_rates], axis=1)
# Out:
# maturity    1 month      Y1      Y2      Y3      Y4      Y5      Y6      Y7  \
# 2025-06-01  1.9364% 1.8089% 1.8294% 1.9050% 2.0084% 2.1230% 2.2387% 2.3498%
# 2025-07-01  1.9004% 1.8187% 1.8568% 1.9475% 2.0635% 2.1887% 2.3134% 2.4322%
# 2025-08-01  1.8981% 1.8793% 1.9179% 2.0025% 2.1115% 2.2313% 2.3529% 2.4710%
# 2025-09-01  1.9053% 1.9252% 1.9609% 2.0373% 2.1375% 2.2495% 2.3655% 2.4800%
#
# maturity        Y8      Y9  ...     Y21     Y22     Y23     Y24     Y25  \
# 2025-06-01 2.4531% 2.5470%  ... 3.0084% 3.0088% 3.0059% 2.9999% 2.9913%
# 2025-07-01 2.5423% 2.6422%  ... 3.1552% 3.1589% 3.1590% 3.1560% 3.1501%
# 2025-08-01 2.5822% 2.6847%  ... 3.2504% 3.2574% 3.2605% 3.2603% 3.2570%
# 2025-09-01 2.5896% 2.6921%  ... 3.2943% 3.3039% 3.3095% 3.3115% 3.3103%
#
# maturity       Y26     Y27     Y28     Y29     Y30
# 2025-06-01 2.9803% 2.9673% 2.9525% 2.9362% 2.9185%
# 2025-07-01 3.1418% 3.1312% 3.1187% 3.1044% 3.0886%
# 2025-08-01 3.2509% 3.2425% 3.2319% 3.2194% 3.2052%
# 2025-09-01 3.3062% 3.2995% 3.2905% 3.2795% 3.2667%
#
# [4 rows x 31 columns]

# %%
date_now = euro_spot_rates.index[-1].date()
date_1_mth_ago = date_now + relativedelta(months=-1)
date_2_mth_ago = date_now + relativedelta(months=-2)
offsets = [relativedelta(years=+maturity) for maturity in year_maturities]
monthly_offsets = [relativedelta(), relativedelta(months=+1)] #, relativedelta(months=+3), relativedelta(months=+6)]
offsets = monthly_offsets + offsets

# %%
# Define Euro yield curves
curve = curves.YieldCurve(date_now, offsets, np.append(
            np.append(overnight_rate.loc[str(mm_rates.index[-1])], mm_rates.iloc[-1].to_numpy()),
            euro_spot_rates.iloc[-1].to_numpy()), compounding_freq=0)
curve_1_mth_ago = curves.YieldCurve(date_1_mth_ago, offsets, np.append(
            np.append(overnight_rate[date_1_mth_ago:date_1_mth_ago+BDay()], mm_rates[date_1_mth_ago:date_1_mth_ago+BDay()].to_numpy()[0,:]),
            euro_spot_rates[date_1_mth_ago:date_1_mth_ago+BDay()].to_numpy()[0,:]), compounding_freq=0)
curve_2_mth_ago = curves.YieldCurve(date_2_mth_ago, offsets, np.append(
            np.append(overnight_rate[date_2_mth_ago:date_2_mth_ago+BDay()].to_numpy(), mm_rates[date_2_mth_ago:date_2_mth_ago+BDay()].to_numpy()[0,:]),
            euro_spot_rates[date_2_mth_ago:date_2_mth_ago+BDay()].to_numpy()[0,:]), compounding_freq=0)

# %%
# Here I will switch to annual compounding frequency for preparing curve points for display.
curve_points = curve.get_curve_points(120, 1)
curve_points_1_mth_ago = curve_1_mth_ago.get_curve_points(120, 1)
curve_points_2_mth_ago = curve_2_mth_ago.get_curve_points(120, 1)
# Uncomment if you want to display points with a continuous compounding frequency.
# curve_points = curve.get_curve_points(120)
# curve_points_1_mth_ago = curve_1_mth_ago.get_curve_points(120)
# curve_points_2_mth_ago = curve_2_mth_ago.get_curve_points(120)
curve_points.rename('Euro riskless rate', inplace=True)
curve_points_1_mth_ago.rename(curve_points.name + ' (1 month prior)', inplace=True)
curve_points_2_mth_ago.rename(curve_points.name + ' (2 months prior)', inplace=True)

# Replacing indices for sake of better visualization
curve_points_1_mth_ago = curve_points_1_mth_ago.set_axis(curve_points.index)
curve_points_2_mth_ago = curve_points_2_mth_ago.set_axis(curve_points.index)
df = pd.concat([curve_points, curve_points_1_mth_ago, curve_points_2_mth_ago], axis=1)

# %%
df
# Out:
#             Euro riskless rate  Euro riskless rate (1 month prior)  \
# 2025-09-01             1.9513%                             1.9507%
# 2025-12-02             1.8901%                             1.8727%
# 2026-03-04             1.8855%                             1.8543%
# 2026-06-04             1.9122%                             1.8708%
# 2026-09-04             1.9449%                             1.8974%
# ...                        ...                                 ...
# 2054-08-28             3.3340%                             3.2719%
# 2054-11-28             3.3308%                             3.2684%
# 2055-02-28             3.3275%                             3.2647%
# 2055-06-01             3.3241%                             3.2610%
# 2055-09-01             3.3206%                             3.2571%
#
#             Euro riskless rate (2 months prior)
# 2025-09-01                              1.9490%
# 2025-12-02                              1.8743%
# 2026-03-04                              1.8395%
# 2026-06-04                              1.8310%
# 2026-09-04                              1.8356%
# ...                                         ...
# 2054-08-28                              3.1532%
# 2054-11-28                              3.1493%
# 2055-02-28                              3.1452%
# 2055-06-01                              3.1411%
# 2055-09-01                              3.1368%
#
# [120 rows x 3 columns]

# %% [markdown]
# #### Compounding frequency
# The rates presented in this section of the notebook use an annual compounding frequency.

# %%
ANNUAL_COMP_SFX = ' (Annual Compounding)'
ax = df.iloc[:,0:1].plot(figsize=(20,10), grid=True,
             title='Euro Riskless Rate Curve over month ' + date_now.strftime('%Y-%m') + ANNUAL_COMP_SFX,
             xlim=(df.index[0], df.index[-1]), xticks=df.index[::4], xlabel='', rot=45)
df.iloc[:,1:2].plot(ax=ax, grid=True, xticks=df.index[::4], rot=45, linestyle='--', color=['#1f77b4'])
df.iloc[:,2:3].plot(ax=ax, grid=True, xticks=df.index[::4], rot=45, linestyle=':', color=['#1f77b4'])
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, df.index[::4])))

# %%
print('An average shift of {:+.2f}bps between {:%Y-%m} and {:%Y-%m} across maturities'.format(
    (df.iloc[:,0]-df.iloc[:,1]).mean() * 10000,
    euro_spot_rates.index[-1].date(), euro_spot_rates.index[-2].date()))
# Out:
# An average shift of +3.37bps between 2025-09 and 2025-08 across maturities

# %%
year_split = date(2033, 11, 1)

# %%
print('An average shift of {:+.2f}bps between {:%Y-%m} and {:%Y-%m} for maturities up to {:%Y-%m}'.format(
    (df.loc[:year_split,df.columns[0]]-df.loc[:year_split,df.columns[1]]).mean() * 10000,
    euro_spot_rates.index[-1].date(), euro_spot_rates.index[-2].date(), year_split))
# Out:
# An average shift of +2.46bps between 2025-09 and 2025-08 for maturities up to 2033-11

# %%
print('An average shift of {:+.2f}bp between {:%Y-%m} and {:%Y-%m} for maturities from {:%Y-%m}'.format(
    (df.loc[year_split:,df.columns[0]]-df.loc[year_split:,df.columns[1]]).mean() * 10000,
    euro_spot_rates.index[-1].date(), euro_spot_rates.index[-2].date(), year_split))
# Out:
# An average shift of +3.72bp between 2025-09 and 2025-08 for maturities from 2033-11

# %%
offset_in_years = 3

# %%
print('Average short-term (<{:d}y) riskless yield: {:.2%}'.format(offset_in_years,
    df.loc[:(euro_spot_rates.index[-1].date()+relativedelta(years=+offset_in_years)),df.columns[0]].mean()))
# Out:
# Average short-term (<3y) riskless yield: 1.96%

# %%
print('Average long-term (>{:d}y) riskless yield: {:.2%}'.format(offset_in_years,
    df.loc[(euro_spot_rates.index[-1].date()+relativedelta(years=+offset_in_years)):,df.columns[0]].mean()))
# Out:
# Average long-term (>3y) riskless yield: 3.04%

# %%
print('Long-term (>{:d}y) riskless yield: {:.2%}-{:.2%}'.format(offset_in_years,
    df.loc[(euro_spot_rates.index[-1].date()+relativedelta(years=+offset_in_years)):,df.columns[0]].min(),
    df.loc[(euro_spot_rates.index[-1].date()+relativedelta(years=+offset_in_years)):,df.columns[0]].max()))
# Out:
# Long-term (>3y) riskless yield: 2.06%-3.37%

# %%
df.iloc[:,0:1].max()
# Out:
# Euro riskless rate   3.3670%
# dtype: float64

# %%
df.iloc[:,0:1].min()
# Out:
# Euro riskless rate   1.8855%
# dtype: float64

# %%
df.iloc[:,0:1].idxmin()
# Out:
# Euro riskless rate   2026-03-04
# dtype: datetime64[ns]

# %%
df.iloc[-1,0]-df.iloc[-1,2]
# Out:
# np.float64(0.0018376773226824739)
