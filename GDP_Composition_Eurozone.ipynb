# %% [markdown]
# # Euro Area Real GDP and its Composition by Industry and Expenditure
#
# This notebook analyzes **real GDP** in the Euro Area, its long-term trends, and how its composition has evolved over time.
#
# There are three main approaches to measuring GDP:
#
# 1. **Expenditure Approach**:
#    GDP = Household & NPISH consumption + Government consumption + Gross fixed capital formation + Changes in inventories & valuables + Net exports
#
# 2. **Income Approach**:
#    GDP = Compensation of employees + Gross operating surplus / mixed income + Taxes on production and imports less subsidies
#    (Note: pure income components are generally only available in current prices)
#
# 3. **Value-Added (Production) Approach**:
#    GDP = Sum of gross value added by all industries + Taxes less subsidies on products
#
# In this notebook I focus on the **Expenditure** and **Value-Added (Production)** approaches.
#
# **NB**: It’s easy to adjust the rest of this notebook to analyse a specific EU country or a different geographical aggregate. By default the analysis is performed for the Euro Area (`geo = 'EA'`). Required adjustments can be made in the configuration Cell 3 below.
#
# ### Structure
# - Evolution of aggregate real GDP
# - Breakdown and trends by major expenditure category
# - Contributions of each expenditure category to overall real GDP growth (including YTD analysis)
# - Breakdown and trends by major industry groups (NACE Rev. 2 A*10)
# - Contributions of each industry to overall real GDP growth (including YTD analysis)

# %%
# Uncomment if running in Google Colaboratory, otherwise the import of the curves module in the cell below will fail
# Install the latest version of eurostat
# !pip install eurostat -U

# %%
import pandas as pd
import numpy as np
import matplotlib.ticker as mtick
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date
import math

import eurostat

from utils.plotting import get_recession_periods, add_recession_shading, plot_contributions_waterfall, make_ytd_suffix
from utils.euro_area import load_cepr_recession_indicator
from stock_market import CapChangePlotter

# %%
geo_area = 'EA'
geo_label = 'Eurozone'

# geo_area = 'NL'
# geo_label = 'NL'

# geo_area = 'PL'
# geo_label = 'PL'

# Other possible values to the geo_area code can be obtained with:
# eurostat.get_par_values('namq_10_a10', 'geo')

# %%
report_start = date.fromisoformat('1996-01-01')
report_end = date.today()

# %% [markdown]
# ### Euro Area Recession Indicator (CEPR)
# The recession periods for the Euro Area are obtained from the **CEPR-EABCN Euro Area Business Cycle Dating Committee**, the European counterpart to the NBER.
#
# - Official source: [CEPR-EABCN Chronology](https://eabcn.org/dbc/peaksandtroughs/chronology-euro-area-business-cycles)
# - I use the **"Peak excluded"** version, which follows the same trough-method convention as FRED's [USREC](https://fred.stlouisfed.org/series/USREC) / [USRECQ](https://fred.stlouisfed.org/series/USRECQ).

# %%
recession_ea = load_cepr_recession_indicator()
recessions = get_recession_periods(recession_ea)

# %% [markdown]
# ## Euro Area GDP YoY growth

# %%
# Querying for non seasonally adjusted all-items Eurozone GDP data in chained linked volumes of 2010
real_gdp = eurostat.get_data_df('namq_10_gdp', filter_pars={
    'startPeriod': report_start, 'unit': 'CLV10_MEUR', 's_adj': 'NSA', 'na_item': 'B1GQ', 'geo': geo_area}).iloc[:, 4:]
real_gdp = real_gdp.set_index(real_gdp.columns[0]).T
real_gdp = real_gdp.set_axis(pd.DatetimeIndex(real_gdp.index, 'QS'))

# To calculate the annual rate of GDP growth I sum up the non-seasonally adjusted GDP over the last 4 quarters.
# If Eurostat were publishing seasonally adjusted GDP data at annual volumes (as is the case in the US),
# I could calculate the mean over the past 4 quarters and use it as the actual annual GDP. 
real_gdp = real_gdp.rolling(4).sum().pct_change(4, fill_method=None).dropna()
real_gdp.rename(columns={'EA': 'Real GDP'}, inplace=True)
real_gdp.columns.names = [None]

# %%
ax = real_gdp.iloc[:,0].plot(figsize=(20,10), grid=True, title=f'{geo_label} Real GDP Growth (Trailing 12-Month YoY)',
                   xticks=real_gdp.index[::4], xlabel='', rot=45)#, yticks=np.arange(-.15, .2, 0.025))
ax.axhline(y=0, lw=2, c='k')
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
ax2 = ax.twiny()
real_gdp.iloc[:,0].plot.bar(ax=ax2, xlabel='', legend=False, x_compat=True)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
h_line = ax.axhline(y=real_gdp.iloc[:,0].mean(), ls='--', c='#1f77b4', label='Mean level of Real GDP growth')
ax.legend(handles=[h_line])
add_recession_shading(ax, recessions, label='CEPR-EABCN Recession Periods')
ax2.xaxis.set_major_locator(mtick.NullLocator())
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, real_gdp.index[::4])))
sns.despine(left=True, bottom=True)

# %%
print(f'Mean level of annual rate of real GDP growth in {geo_label} since {real_gdp.index[0]:%Y-%m-%d}: '
      f'{real_gdp.iloc[:,0].mean():.2%}')
# Out:
# Mean level of annual rate of real GDP growth in Eurozone since 1997-10-01: 1.63%

# %% [markdown]
# ## Composition of Euro Area GDP using the Expenditure Approach
#
# In this section I decompose Euro Area real GDP into its main expenditure components (chain-linked volumes):
#
# * Household and NPISH final consumption expenditure (`P31_S14_S15`)
# * General government final consumption expenditure (`P3_S13`)
# * Gross fixed capital formation (`P51G`)
# * Net exports of goods and services (`P6` − `P7`)
#
# Official GDP (`B1GQ`) is also retrieved for cross-checking.
# Because changes in inventories and valuables are not published in real terms for the Euro Area, the residual is calculated as:
#
# $$
# \text{Residual} = \text{GDP} - (\text{Household \& NPISH} + \text{Government} + \text{GFCF} + \text{Net exports})
# $$
#
# This residual captures both inventories/valuables and the statistical discrepancy that arises when balancing the expenditure and production approaches.
#
# I use Eurostat’s `namq_10_gdp` series.

# %%
# Constants
EXP_UNIT = 'CLV10_MEUR'
HOUSEHOLD_LABEL   = 'Household & NPISH consumption'
GOVERNMENT_LABEL  = 'Government consumption'
GFCF_LABEL        = 'Gross fixed capital formation'
EXPORTS_LABEL     = 'Exports of goods and services'
IMPORTS_LABEL     = 'Imports of goods and services'
NET_EXPORTS_LABEL = 'Net exports'
RESIDUAL_LABEL    = 'Residual (inventories & discrepancy)'
TOTAL_LABEL       = 'Total'

EXP_ITEMS = {
    'P31_S14_S15': HOUSEHOLD_LABEL,
    'P3_S13':      GOVERNMENT_LABEL,
    'P51G':        GFCF_LABEL,
    'P6':          EXPORTS_LABEL,
    'P7':          IMPORTS_LABEL,
    'B1GQ':        TOTAL_LABEL
}

def get_gdp_expenditure_components(s_adjustment=True, geo_area='EA'):
    raw = eurostat.get_data_df('namq_10_gdp', filter_pars={
        'startPeriod': report_start,
        'unit': EXP_UNIT,
        's_adj': 'SCA' if s_adjustment else 'NSA',
        'na_item': list(EXP_ITEMS.keys()),
        'geo': geo_area
    })

    time_cols = [c for c in raw.columns if isinstance(c, str) and '-Q' in c]
    
    df = raw.set_index('na_item')[time_cols].T.rename(columns=EXP_ITEMS).astype(float)
    
    df.index = pd.PeriodIndex(df.index, freq='Q').to_timestamp()
    df = df.dropna(how='all')

    # Derive net exports and drop the gross series
    df[NET_EXPORTS_LABEL] = df[EXPORTS_LABEL] - df[IMPORTS_LABEL]
    df = df.drop(columns=[EXPORTS_LABEL, IMPORTS_LABEL])

    # Residual (inventories + statistical discrepancy)
    df[RESIDUAL_LABEL] = df[TOTAL_LABEL] - df[HOUSEHOLD_LABEL] - df[GOVERNMENT_LABEL] - df[GFCF_LABEL] - df[NET_EXPORTS_LABEL]
    df[TOTAL_LABEL] = df.pop(TOTAL_LABEL)

    df.columns.name = None
    # Desired column order
    desired_order = [RESIDUAL_LABEL, HOUSEHOLD_LABEL, GOVERNMENT_LABEL, GFCF_LABEL, NET_EXPORTS_LABEL, TOTAL_LABEL]
    df = df[[c for c in desired_order if c in df.columns]]
    
    return df

# %%
gdp_exp_components = get_gdp_expenditure_components(geo_area=geo_area).dropna()
gdp_exp_total = gdp_exp_components.loc[:, TOTAL_LABEL]
gdp_exp_components = gdp_exp_components.iloc[:,:-1]

# %%
GRAPH_TITLE_GDP_EXP_COMPONENTS = f'Composition of {geo_label} GDP By Expenditure'
GRAPH_TITLE_GDP_EXP_COMPONENTS_PCT_CHG = f'Contributions to Percent Change in {geo_label} Real GDP by Expenditure Type'
LEFT_Y_AXIS_LABEL = 'Billions of Euros'

# %%
# Dealing with a quirk that DataFrame.plot.area requires all columns to have either positive or negative values
signed_cols = [RESIDUAL_LABEL]
positive_cols = gdp_exp_components.columns.difference(signed_cols)
# Positive parts of signed series that actually have positive values
signed = gdp_exp_components[signed_cols]
pos_signed = signed.clip(lower=0).loc[:, lambda df: (df > 0).any()]

# Putting the positive signed parts first (bottom of the stack), then the always-positive columns
all_pos = pd.concat([pos_signed, gdp_exp_components[positive_cols]], axis=1)

# Negative parts
all_neg = signed.clip(upper=0).loc[:, lambda df: (df < 0).any()]

colors = {
    HOUSEHOLD_LABEL: 'C0',
    GOVERNMENT_LABEL: 'C1',
    GFCF_LABEL: 'C2',
    EXPORTS_LABEL: 'C3',
    IMPORTS_LABEL: 'C4',
    NET_EXPORTS_LABEL: 'C5',
    RESIDUAL_LABEL: 'C6'
}

# %%
# ax = gdp_exp_components.plot.area(figsize=(20,10), grid=True, title=GRAPH_TITLE_GDP_EXP_COMPONENTS + ' (quarterly rate)',
#                                   xticks=gdp_exp_components.index[::2], xlabel='', ylabel=LEFT_Y_AXIS_LABEL, rot=45)
# ax.yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: '{:,.0f}'.format(x/1000)))
# _ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, gdp_exp_components.index[::2])))


ax = all_pos.plot.area(figsize=(20,10), grid=True, title=GRAPH_TITLE_GDP_EXP_COMPONENTS + ' (quarterly rate)',
                       xticks=all_pos.index[::2], xlabel='', rot=45, color=[colors[c] for c in all_pos.columns])
all_neg.plot.area(ax=ax, grid=True, xticks=all_pos.index[::2], xlabel='', rot=45, ylabel=LEFT_Y_AXIS_LABEL,
                  color=[colors[c] for c in all_neg.columns])
add_recession_shading(ax, recessions, add_legend_entry=False, label='CEPR-EABCN Recession Periods')
ax.yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: '{:,.0f}'.format(x/1000)))
# Unique legend (removes the duplicate)
handles, labels = ax.get_legend_handles_labels()
unique = dict(zip(labels, handles))          # keep first occurrence
ax.legend(unique.values(), unique.keys(), frameon=True)
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, all_pos.index[::2])))

# %%
# # Converting to percentages by dividing by total
# gdp_exp_components_pct = gdp_exp_components.divide(gdp_exp_total, axis=0)

# Converting to percentages by dividing by total
all_pos_pct = all_pos.divide(gdp_exp_total, axis=0)
all_neg_pct = all_neg.divide(gdp_exp_total, axis=0)

# %%
ax = all_pos_pct.plot.area(figsize=(20,10), grid=True, title=GRAPH_TITLE_GDP_EXP_COMPONENTS,
                           xticks=all_pos_pct.index[::2], xlabel='', rot=45,
                           color=[colors[c] for c in all_pos_pct.columns], yticks=np.arange(0, 1.01, .1))
all_neg_pct.plot.area(ax=ax, grid=True, xticks=all_pos_pct.index[::2], xlabel='', rot=45, color=[colors[c] for c in all_neg_pct.columns])
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
ax.legend(unique.values(), unique.keys())
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, all_pos_pct.index[::2])))

# %%
pd.options.display.float_format = '{:.2%}'.format
print(all_pos_pct.iloc[-1,:].sort_values(ascending=False).head(6))
# Out:
# Household & NPISH consumption          53.20%
# Government consumption                 22.29%
# Gross fixed capital formation          21.39%
# Net exports                             2.55%
# Residual (inventories & discrepancy)    0.57%
# Name: 2026-01-01 00:00:00, dtype: float64

# %% [markdown]
# ## Contributions to Percentage Change in Eurozone Real GDP by Expenditure Type
# It's interesting to analyze how much each expenditure type added to the overall Real GDP growth over a number of years. This lets us see which types of spend are driving the economy.
#
# The way I break down overall Real GDP percentage change over a period into those of individual expenditures so that they all sum up to the same number is by using the following formula. If X = Y + Z, then:
#
# percentage change of $X = {X_2 - X_1 \over X_1} = {Y_2 + Z_2 - Y_1 - Z_1 \over Y_1 + Z_1} = {Y_2 - Y_1  \over Y_1 + Z_1} + {Z_2 - Z_1 \over Y_1 + Z_1}$

# %%
periods = [5, 3]
gdp_exp_total_pct_chg = pd.DataFrame([gdp_exp_total.pct_change(4*period).iloc[-1] for period in periods], 
                                     index=['Over past {:d} years'.format(period) for period in periods],
                                     columns=['Percentage Change'])
gdp_exp_total_pct_chg
# Out:
#                    Percentage Change
# Over past 5 years             11.00%
# Over past 3 years              3.31%

# %%
gdp_exp_components_pct_chg = pd.concat(
    [((gdp_exp_components - gdp_exp_components.shift(4*period)).divide(gdp_exp_total.shift(4*period), axis=0)).iloc[-1] for period in periods],
                                    axis=1)
gdp_exp_components_pct_chg.columns = ['Over past {:d} years'.format(period) for period in periods]

# %%
plotter = CapChangePlotter()
for column in gdp_exp_components_pct_chg.columns:
    _ = plotter.plot_cap_change_bars(changes=gdp_exp_components_pct_chg.loc[:, column].sort_values(), mode="mixed", cut_off=20,
                                     graph_title=f'{GRAPH_TITLE_GDP_EXP_COMPONENTS_PCT_CHG} '
                                                 f'({column} = {gdp_exp_total_pct_chg.loc[column].squeeze():.2%})')

# %% [markdown]
# ### Contributions to Percentage Change in Eurozone Real GDP by Expenditure Type YTD

# %%
# Measuring growth YTD with the corresponding intervals in previous years.
month = gdp_exp_components.index[-1].month
gdp_exp_total_ytd = gdp_exp_total.loc[gdp_exp_total.index.month <= month]
gdp_exp_total_ytd = gdp_exp_total_ytd.resample('YS-JAN').sum().pct_change()

# %%
print(f'YTD GDP grew by {gdp_exp_total_ytd.iloc[-1]:.2%} YoY')
# Out:
# YTD GDP grew by 0.99% YoY

# %%
qtd = gdp_exp_components.index[-1].quarter
gdp_exp_components_pct_chg_ytd =\
    ((gdp_exp_components.rolling(qtd).mean() - gdp_exp_components.rolling(qtd).mean().shift(4)).divide(
        gdp_exp_total.rolling(qtd).mean().shift(4), axis=0)).iloc[-1]
gdp_exp_components_pct_chg_ytd.name = 'YTD to previous year'
gdp_exp_components_pct_chg_ytd = gdp_exp_components_pct_chg_ytd.sort_values()
gdp_exp_components_pct_chg_ytd
# Out:
# Net exports                            -1.05%
# Gross fixed capital formation           0.16%
# Residual (inventories & discrepancy)    0.36%
# Government consumption                  0.59%
# Household & NPISH consumption           0.93%
# Name: YTD to previous year, dtype: float64

# %%
df = gdp_exp_components_pct_chg_ytd.to_frame()
# Calculating the running totals
df['Running_Total'] = df.iloc[:, 0].cumsum()
df['Shifted_Total'] = df.loc[:, 'Running_Total'].shift(1).fillna(0)

# %%
_, _ = plot_contributions_waterfall(df, gdp_exp_total_ytd.iloc[-1], f'Contributions per expenditure to {geo_label} YoY GDP growth',
                                    total_label=f'{geo_label} YoY GDP growth', ytd_suffix=make_ytd_suffix(gdp_exp_components.index))

# %% [markdown]
# ## Composition of Euro Area GDP using Value-Added (Production) Approach
# In this section of the notebook I look at the real value added (represents the sum of the costs-incurred and the incomes-earned in production, and consists of compensation of employees, taxes on production and imports, less subsidies, and gross operating surplus) for each constituent industry of Euro Area GDP and how it changed over the past 5 and 10 years as well as year to date. In other words I break down real GDP growth over a given timeframe into growth of individual industries.
#
# I use chained linked volumes (2010) expressed in millions of euros as the unit of real measure of GDP and seasonally and calendar adjusted series. This is more appropriate as Eurostat publishes quarterly GDP data using quarterly rather than annual rates.

# %%
def get_gdp_components(s_adjustment=True, geo_area = 'EA'):
    gdp_components = eurostat.get_data_df('namq_10_a10', filter_pars={
        'startPeriod': report_start, 'unit': 'CLV10_MEUR', 's_adj': 'SCA' if s_adjustment else 'NSA',
        'nace_r2': ['A', 'B-E', 'C', 'F', 'G-I', 'J', 'K', 'L', 'M_N', 'O-Q', 'R-U', 'TOTAL'], 'geo': geo_area}).iloc[:, 5:]
    gdp_components = gdp_components.set_index(gdp_components.columns[0]).T
    gdp_components = gdp_components.set_axis(pd.DatetimeIndex(gdp_components.index, 'QS')).dropna()
    gdp_components.columns.names = [None]
    gdp_components.columns = ['Agriculture, forestry and fishing', 'Industry (except construction)', 'Manufacturing',
                              'Construction', 'Wholesale and retail trade, transport...',
                              'Information and communication', 'Financial and insurance activities',
                              'Real estate activities',
                              'Professional, scientific and technical activities...',
                              'Public administration, defence, education...',
                              'Arts, entertainment and recreation...', 'Total']
    return gdp_components

# %% [markdown]
# Eurostat uses [the NACE Rev.2 classification](https://eur-lex.europa.eu/LexUriServ/LexUriServ.do?uri=OJ:L:2010:210:0001:0021:EN:PDF) to define industry breakdowns. It publishes value added and income industry breakdowns only at the so-called `A*10` granularity, i.e. it breaks it down into 10 economic activities. Each of these has a unique `nace_r2` code:
# 1. Agriculture, forestry and fishing
# 1. Industry (except construction), this is also known as industrial production: mining, manufacturing and utilities.
#     1. Manufacturing. Designated with a nace_r2 code of `C`. Since manufacturing is included in Industrial production, it needs to be taken into account to avoid double-counting
# 1. Construction
# 1. Wholesale and retail trade, transport, accommodation and food service activities
# 1. Information and communication
# 1. Financial and insurance activities
# 1. Real estate activities
# 1. Professional, scientific and technical activities; administrative and support service activities
# 1. Public administration, defence, education, human health and social work activities
# 1. Arts, entertainment and recreation; other service activities; activities of household and extra-territorial organizations and bodies
#
# For brevity's sake I use shortened names of the activities in the rest of this notebook for better display.

# %%
gdp_components = get_gdp_components(geo_area=geo_area)
gdp_total = gdp_components.iloc[:,-1]
gdp_components_a10 = gdp_components.iloc[:,[0,1,3,4,5,6,7,8,9,10]]
gdp_components = gdp_components.iloc[:,:-1]

# %%
GRAPH_TITLE_GDP_COMPONENTS = f'Composition of {geo_label} GDP By Value Added'
GRAPH_TITLE_GDP_COMPONENTS_PCT_CHG = f'Contributions to Percentage Change in {geo_label} Real GDP by Industry Group'
LEFT_Y_AXIS_LABEL = 'Billions of Euros'

# %%
ax = gdp_components_a10.plot.area(figsize=(20,10), grid=True, title=GRAPH_TITLE_GDP_COMPONENTS + ' (quarterly rate)',
                                  xticks=gdp_components_a10.index[::2], xlabel='', ylabel=LEFT_Y_AXIS_LABEL, rot=45)
ax.yaxis.set_major_formatter(mtick.FuncFormatter(lambda x, _: '{:,.0f}'.format(x/1000)))
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, gdp_components_a10.index[::2])))

# %%
# Converting to percentages by dividing by total
gdp_components_pct = gdp_components_a10.divide(gdp_components_a10.sum(axis=1), axis=0)

# %%
ax = gdp_components_pct.plot.area(figsize=(20,10), grid=True, title=GRAPH_TITLE_GDP_COMPONENTS,
                                  xticks=gdp_components_pct.index[::2], xlabel='', rot=45,
                                  yticks=np.arange(0, 1.01, .1))
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1))
ax.legend(loc='upper left')
_ = ax.set_xticklabels(list(map('{:%Y-%m}'.format, gdp_components_pct.index[::2])))

# %%
pd.options.display.float_format = '{:.2%}'.format
gdp_components_pct.iloc[-1,:].sort_values(ascending=False)
# Out:
# Wholesale and retail trade, transport...               18.69%
# Public administration, defence, education...           18.54%
# Industry (except construction)                         17.97%
# Professional, scientific and technical activities...   12.52%
# Real estate activities                                 11.30%
# Information and communication                           7.58%
# Financial and insurance activities                      4.50%
# Construction                                            4.24%
# Arts, entertainment and recreation...                   3.20%
# Agriculture, forestry and fishing                       1.48%
# Name: 2026-01-01 00:00:00, dtype: object

# %% [markdown]
# **Conclusion 1**:
#
# The
# * Public administration, defence, education, human health and social work activities
# * Wholesale and retail trade, transport, accommodation and food service activities
# * Industrial production
# * Professional, scientific and technical activities; administrative and support service activities
# * Real estate activities
#
# industries contributed the most (>10%) value added to Eurozone GDP as of the most recent quarter.

# %% [markdown]
# Now let's see what percentage of total GDP output is attributable to the `Manufacturing` industry group. As I explained earlier, it's part of a wider `Industry` category.

# %%
gdp_components.divide(gdp_components_a10.sum(axis=1), axis=0).iloc[-1,2:3]
# Out:
# Manufacturing   15.92%
# Name: 2026-01-01 00:00:00, dtype: object

# %% [markdown]
# ### Contributions to Percentage Change in Euro Are Real GDP by Industry Group
# It's interesting to analyze how much each industry contributed to the overall Real GDP growth over a number of years. This lets us see which industries are contributing the most. I compare cumulative GDP growth over the last 4 quarters (which gives annual growth) with that 5 and 10 years ago. This is more accurate than comparing the output in a given quarter with that same quarter 5 and 10 years ago.
#
# The way I break down overall Real GDP percentage change over a period into contributions of indivudual industries so that they all sum up to the same number is by using the following formula. If X = Y + Z, then:
#
# percentage change of $X = {X_2 - X_1 \over X_1} = {Y_2 + Z_2 - Y_1 - Z_1 \over Y_1 + Z_1} = {Y_2 - Y_1  \over Y_1 + Z_1} + {Z_2 - Z_1 \over Y_1 + Z_1}$

# %% [markdown]
# I will limit analysis to changes over 5 and 10 years. If you want to analyze different intervals, just edit the `periods` variable in the below cell.

# %%
periods = [10, 5]

# %% [markdown]
# For this analysis it's better to switch to not seasonally adjusted data.

# %%
gdp_components = get_gdp_components(False, geo_area=geo_area)
gdp_total = gdp_components.iloc[:,-1]
gdp_components_a10 = gdp_components.iloc[:,[0,1,3,4,5,6,7,8,9,10]]
gdp_components = gdp_components.iloc[:,:-1]

# %% [markdown]
# First let's see by how much the total Real GDP has changed over the specified periods in percentage points.

# %%
gdp_total_pct_chg = pd.DataFrame([gdp_total.rolling(4).sum().pct_change(4*period).iloc[-1] for period in periods], 
                                 index=['Over past {:d} years'.format(period) for period in periods],
                                 columns=['Percentage Change'])
gdp_total_pct_chg
# Out:
#                     Percentage Change
# Over past 10 years             16.16%
# Over past 5 years              14.60%

# %% [markdown]
# Now I break down these overall Real GDP percentage changes into contributions from individual industries so that they sum up to the same real GDP percentage change number.

# %%
gdp_components_pct_chg = pd.concat(
    [((gdp_components_a10.rolling(4).sum() - gdp_components_a10.rolling(4).sum().shift(4*period)).divide(
        gdp_total.rolling(4).sum().shift(4*period), axis=0)).iloc[-1] for period in periods], axis=1)
gdp_components_pct_chg.columns = ['Over past {:d} years'.format(period) for period in periods]

# %%
gdp_components_pct_chg.sort_values(by=gdp_components_pct_chg.columns[0], inplace=True)

# %%
y_max = round(max([series[series.iloc[:] > 0].sum() for _, series in gdp_components_pct_chg.items()]) + .005, 2) + 1e-3
ax = gdp_components_pct_chg.T.plot.bar(figsize=(14,10), stacked=True, title=GRAPH_TITLE_GDP_COMPONENTS_PCT_CHG,
                                       rot=0,# yticks=np.arange(-.01, y_max, .01),
                                       edgecolor='white', linewidth=0.8, width=0.8, fontsize=9)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1, decimals=0))
ax.get_legend().remove()
for c in ax.containers:
    ax.bar_label(c, fmt=c.get_label() + ': {:.2%}', label_type='center', fontsize=9, color='white', fontweight='bold')
ax.grid(axis='y', linestyle='--', alpha=0.7)

# %%
plotter = CapChangePlotter()
for column in gdp_components_pct_chg.columns:
    _ = plotter.plot_cap_change_bars(changes=gdp_components_pct_chg.loc[:, column].sort_values(), mode="mixed", cut_off=20,
                                     graph_title=f'{GRAPH_TITLE_GDP_COMPONENTS_PCT_CHG} ({column})')

# %% [markdown]
# Due to the presence of GDP components not allocated to any particular industry and rounding errors, in Eurostat's `namq_10_a10` series the sum of the output of individual industries doesn't exactly sum up to the total. There's an approximately 5% difference. The below cell checks that the discrepancy is not bigger than 5%.

# %%
assert np.allclose(gdp_components_pct_chg.sum(), gdp_total_pct_chg.squeeze(), rtol=.06)

# %% [markdown]
# **Conclusion 2**: The largest contributions to Eurozone real GDP growth in the past 5 years are:
# * Wholesale and retail trade, transport, accommodation and food service activities
# * Professional, scientific and technical activities; administrative and support service activities
# * Information and communication
# * Public administration, defence, education, human health and social work activities
# * Industrual production
#
# Of these industries:
# * Wholesale and retail trade, transport, accommodation and food service activities
# * Professional, scientific and technical activities; administrative and support service activities
# * Public administration, defence, education, human health and social work activities
# * Industrial production
# are also in the Top-5 biggest contributors to the Eurozone GDP (see Conclusion 1 above).

# %% [markdown]
# Let's compare the top-5 contributing industries over the past 5 and 10 years.

# %%
gdp_components_pct_chg.sort_values(by=gdp_components_pct_chg.columns[0], ascending=False).iloc[:5,:1]
# Out:
#                                                     Over past 10 years
# Information and communication                                    3.66%
# Professional, scientific and technical activiti...               3.42%
# Wholesale and retail trade, transport...                         2.79%
# Public administration, defence, education...                     2.54%
# Industry (except construction)                                   1.95%

# %%
gdp_components_pct_chg.sort_values(by=gdp_components_pct_chg.columns[1], ascending=False).iloc[:5,1:]
# Out:
#                                                     Over past 5 years
# Wholesale and retail trade, transport...                        4.22%
# Professional, scientific and technical activiti...              2.48%
# Information and communication                                   2.23%
# Public administration, defence, education...                    2.16%
# Industry (except construction)                                  1.47%

# %% [markdown]
# **Conclusion 3**: Over the past 5 years `Information and communication` industry groups dropped from the largest real GDP contributors to the 3<sup>rd</sup> largest.

# %% [markdown]
# ### Contributions to Percentage Change in Euro Area Real GDP by Industry Group YTD

# %%
# Measuring growth YTD with the corresponding intervals in previous years.
month = gdp_components.index[-1].month
gdp_total_ytd = gdp_total.loc[gdp_total.index.month <= month]
gdp_total_ytd = gdp_total_ytd.resample('YS-JAN').sum().pct_change(fill_method=None)

# %%
print(f'YTD GDP grew by {gdp_total_ytd.iloc[-1]:.2%}')
# Out:
# YTD GDP grew by 0.83%

# %%
qtd = gdp_components.index[-1].quarter

# %% [markdown]
# The following industries contributed below-stated percentage points to this growth:

# %%
gdp_components_pct_chg_ytd =\
    ((gdp_components.rolling(qtd).sum() - gdp_components.rolling(qtd).sum().shift(4)).divide(
        gdp_total.rolling(qtd).sum().shift(4), axis=0)).iloc[-1]
gdp_components_pct_chg_ytd.name = 'YTD to previous year'
gdp_components_pct_chg_a10_ytd = gdp_components_pct_chg_ytd.iloc[[0,1,3,4,5,6,7,8,9,10]].sort_values()
gdp_components_pct_chg_a10_ytd
# Out:
# Industry (except construction)                         -0.41%
# Construction                                            0.01%
# Agriculture, forestry and fishing                       0.02%
# Arts, entertainment and recreation...                   0.02%
# Financial and insurance activities                      0.06%
# Professional, scientific and technical activities...    0.19%
# Real estate activities                                  0.22%
# Information and communication                           0.25%
# Public administration, defence, education...            0.26%
# Wholesale and retail trade, transport...                0.30%
# Name: YTD to previous year, dtype: float64

# %% [markdown]
# `Manufacturing`, which is a constituent of `Industry`, contributed the following percentage to GDP growth YTD:

# %%
gdp_components_pct_chg_ytd.iloc[2:3]
# Out:
# Manufacturing   -0.48%
# Name: YTD to previous year, dtype: float64

# %%
gdp_components_pct_chg_a10_ytd = pd.concat([gdp_components_pct_chg_a10_ytd,
                                            pd.Series([gdp_total_ytd.iloc[-1] - gdp_components_pct_chg_a10_ytd.sum()], ['Not Allocated'])])
df = gdp_components_pct_chg_a10_ytd.to_frame()
# Calculating the running totals
df['Running_Total'] = df.iloc[:, 0].cumsum()
df['Shifted_Total'] = df.loc[:, 'Running_Total'].shift(1).fillna(0)

# Remove the 'not allocated' column when not required
df = df.loc[~np.isclose(df.iloc[:,0], 0., atol=1e-4), :]

# %%
_, _ = plot_contributions_waterfall(df, gdp_total_ytd.iloc[-1], f'Contributions per industry to {geo_label} YoY GDP growth',
                                    total_label=f'{geo_label} YoY GDP growth', ytd_suffix=make_ytd_suffix(gdp_components.index))
